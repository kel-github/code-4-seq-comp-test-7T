# %%
import nilearn.plotting as niplt # for debugging
import nilearn.image as img
import pandas as pd
import nibabel as nib
import os

# %%
f = '/scratch/qbi/uqkgarn1/STRIWP1/derivatives/sub-01/ses-02/func/sub-01_ses-02_task-learnAtt_acq-TR700_echo-1_space-T1w_desc-preproc_bold_combined.nii.gz'
niplt.plot_epi(img.mean_img(f), threshold=None)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-d7d58c10d8c6> in <module>
#       1 f = '/scratch/qbi/uqkgarn1/STRIWP1/derivatives/sub-01/ses-02/func/sub-01_ses-02_task-learnAtt_acq-TR700_echo-1_space-T1w_desc-preproc_bold_combined.nii.gz'
# ----> 2 niplt.plot_epi(img.mean_img(f), threshold=None)
#
# /opt/miniconda-latest/envs/neuro/lib/python3.6/site-packages/nilearn/plotting/img_plotting.py in plot_epi(epi_img, cut_coords, output_file, display_mode, figure, axes, title, annotate, draw_cross, black_bg, cmap, vmin, vmax, **kwargs)
#     622                        threshold=None, annotate=annotate,
#     623                        draw_cross=draw_cross, black_bg=black_bg,
# --> 624                        cmap=cmap, vmin=vmin, vmax=vmax, **kwargs)
#     625     return display
#     626
#
# TypeError: plot_img() got multiple values for keyword argument 'threshold'

# %%
mks = '/scratch/qbi/uqkgarn1/STRIWP1/derivatives/glmTDFAST/sub-01/TR1920/THRSH/thrVS_spmT_0001.nii.gz'
T1 = '/scratch/qbi/uqkgarn1/STRIWP1/derivatives/sub-05/anat/sub-05_desc-preproc_T1w.nii.gz'

# %%
niplt.plot_roi(roi_img=mks, bg_img=T1)

# %%
mks = '/scratch/qbi/uqkgarn1/STRIWP1/derivatives/glmFIR/sub-01/TR1510/FLGLM/PARAMS/rCN_1.nii.gz'
T1 = '/scratch/qbi/uqkgarn1/STRIWP1/derivatives/sub-05/anat/sub-05_desc-preproc_T1w.nii.gz'

# %%
niplt.plot_roi(roi_img=mks, bg_img=T1)

# %%
mks = '/scratch/qbi/uqkgarn1/STRIWP1/derivatives/glmFIR/sub-01/TR1510/FLGLM/PARAMS/rCN_2.nii.gz'
niplt.plot_roi(roi_img=mks, bg_img=T1)

# %%
mks = '/scratch/qbi/uqkgarn1/STRIWP1/derivatives/glmFIR/sub-01/TR1510/FLGLM/PARAMS/rCN_3.nii.gz'
niplt.plot_roi(roi_img=mks, bg_img=T1)

# %%
# define subject paths
Basedir =  "/scratch/qbi/uqkgarn1/"
betas = ['/scratch/qbi/uqkgarn1/STRIWP1/derivatives/glm/sub-05/TR1920/MASKS/CNR/ALLROIS_CNR_0001.nii.gz', 
         '/scratch/qbi/uqkgarn1/STRIWP1/derivatives/glm/sub-05/TR1920/MASKS/CNR/ALLROIS_CNR_0002.nii.gz']
T1 = '/scratch/qbi/uqkgarn1/STRIWP1/derivatives/sub-01/anat/sub-01_desc-preproc_T1w.nii.gz'
#maks = 'tmp/tmpjqb9ra1c/estimate/mask.nii'

# %%
niplt.plot_stat_map(stat_map_img=betas[0], bg_img=T1, cut_coords=(10,-8,-12), colorbar=True)

# %%
#resMS = '/scratch/qbi/uqkgarn1/STRIWP1/derivatives/glm/sub-01/TR700/FLGLM/ResMS.nii.gz'
niplt.plot_img(betas[0], colorbar=True)

# %%
resMS = '/scratch/qbi/uqkgarn1/STRIWP1/derivatives/glm/sub-01/TR1510/FLGLM/ResMS.nii.gz'
niplt.plot_img(resMS, colorbar=True)

# %% [markdown]
# # checking files present for sub 1, TR 1510

# %%
T2s = '/scratch/qbi/uqkgarn1/STRIWP1/derivatives/sub-%s/ses-%s/func/sub-%s_ses-%s_task-learnAtt_acq-TR700_space-T1w_desc-preproc_bold.nii.gz'

# %%
sub = '05'
ses = '04'
fname = T2s % (sub, ses, sub, ses)
fname
# Out:
# '/scratch/qbi/uqkgarn1/STRIWP1/derivatives/sub-05/ses-04/func/sub-05_ses-04_task-learnAtt_acq-TR700_space-T1w_desc-preproc_bold.nii.gz'

# %%
T2_img = nib.load(fname)

# %%
T2_img.shape
# Out:
# (71, 89, 71, 923)

# %%
ses = '03'
T2_img = nib.load(fname)
T2_img.shape

# %% [markdown]
# Both have 500 images on the time dimenstion so:

# %% [markdown]
# ## Check dimensionality of thresholded t-images

# %%
timg = nib.load('/scratch/qbi/uqkgarn1/STRIWP1/derivatives/glmTDFAST/sub-02/TR700/THRSH/thrFEF_spmT_0001.nii.gz')

# %%
timg.shape
