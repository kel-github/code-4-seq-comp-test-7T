# %%
import nilearn.plotting as niplt # for debugging
import nilearn.image as img
import pandas as pd
import nibabel as nib
import os
import numpy as np

# %%
mks = '/scratch/qbi/uqkgarn1/STRIWP1/derivatives/glmTDFAST_TC/sub-04/TR700/MASK/spmT0003_thresh_bin.nii.gz'
T1 = '/scratch/qbi/uqkgarn1/STRIWP1/derivatives/sub-04/anat/sub-04_desc-preproc_T1w.nii.gz'

# %%
T1 = '/scratch/qbi/uqkgarn1/STRIWP1/derivatives/glm/sub-01/anat/sub-01_desc-masked_T1w.nii.gz'
msk_anat = '/scratch/qbi/uqkgarn1/STRIWP1/derivatives/sub-01/anat/sub-01_desc-brain_mask.nii.gz'
dseg_apar = '/scratch/qbi/uqkgarn1/STRIWP1/derivatives/sub-01/anat/sub-01_desc-aparcaseg_dseg.nii.gz'
desg_aseg = '/scratch/qbi/uqkgarn1/STRIWP1/derivatives/sub-01/anat/sub-01_desc-aseg_dseg.nii.gz'
dseg = '/scratch/qbi/uqkgarn1/STRIWP1/derivatives/sub-01/anat/sub-01_dseg.nii.gz'
T2msk = '/scratch/qbi/uqkgarn1/STRIWP1/derivatives/sub-01/ses-02/func/sub-01_ses-02_task-learnAtt_acq-TR1510_space-T1w_desc-brain_mask.nii.gz'

# %%
niplt.plot_img(img = T2msk)

# %%
niplt.plot_img(img = T1, black_bg = True)

# %%
niplt.plot_img(img = msk_anat)

# %%
niplt.plot_img(img = dseg_apar)

# %%
niplt.plot_img(img = desg_aseg)

# %%
niplt.plot_img(img=dseg)
# Out:
# /opt/miniconda-latest/envs/neuro/lib/python3.6/site-packages/nilearn/image/resampling.py:513: UserWarning: Casting data from int32 to float32
#   warnings.warn("Casting data from %s to %s" % (data.dtype.name, aux))

# %%
niplt.plot_roi(roi_img=mks, bg_img=T1)

# %%
mks = '/scratch/qbi/uqkgarn1/STRIWP1/derivatives/glmTDFAST/sub-01/TR1920/THRSH/thrVS_spmT_0001.nii.gz'
T1 = '/scratch/qbi/uqkgarn1/STRIWP1/derivatives/sub-05/anat/sub-05_desc-preproc_T1w.nii.gz'

# %%
niplt.plot_roi(roi_img=mks, bg_img=T1)

# %%
mks = '/scratch/qbi/uqkgarn1/STRIWP1/derivatives/glmFIR/sub-01/TR1510/FLGLM/PARAMS/rCN_1.nii.gz'
T1 = '/scratch/qbi/uqkgarn1/STRIWP1/derivatives/sub-05/anat/sub-05_desc-preproc_T1w.nii.gz'

# %%
niplt.plot_roi(roi_img=mks, bg_img=T1)

# %%
mks = '/scratch/qbi/uqkgarn1/STRIWP1/derivatives/glmFIR/sub-01/TR1510/FLGLM/PARAMS/rCN_2.nii.gz'
niplt.plot_roi(roi_img=mks, bg_img=T1)

# %%
mks = '/scratch/qbi/uqkgarn1/STRIWP1/derivatives/glmFIR/sub-01/TR1510/FLGLM/PARAMS/rCN_3.nii.gz'
niplt.plot_roi(roi_img=mks, bg_img=T1)

# %%
# define subject paths
Basedir =  "/scratch/qbi/uqkgarn1/"
betas = '/scratch/qbi/uqkgarn1/STRIWP1/derivatives/glmTDFAST_HANDS/sub-04/TR700/THRSH/_TR_700_sub_04/_apply-thrsh0/spmT_0005_thresh.nii.gz'
T1 = '/scratch/qbi/uqkgarn1/STRIWP1/derivatives/sub-04/anat/sub-04_desc-preproc_T1w.nii.gz'
#maks = 'tmp/tmpjqb9ra1c/estimate/mask.nii'

# %%
niplt.plot_stat_map(stat_map_img=betas, bg_img=T1, cut_coords=(10,-8,-12), colorbar=True)

# %%
#resMS = '/scratch/qbi/uqkgarn1/STRIWP1/derivatives/glm/sub-01/TR700/FLGLM/ResMS.nii.gz'
niplt.plot_img(betas[0], colorbar=True)

# %%
resMS = '/scratch/qbi/uqkgarn1/STRIWP1/derivatives/glm/sub-01/TR1510/FLGLM/ResMS.nii.gz'
niplt.plot_img(resMS, colorbar=True)

# %% [markdown]
# # checking files present for sub 5, TR 700

# %% [markdown]
# Using https://bic-berkeley.github.io/psych-214-fall-2016/saving_images.html to match the file dimensions to the motion regressors. Back ups are saved in bkup/

# %%
T2s = '/scratch/qbi/uqkgarn1/STRIWP1/derivatives/glmTDFAST_HANDS/sub-04/TR700/THRSH/_TR_700_sub_04/_apply-thrsh0/spmT_0005_thresh.nii.gz'

# %%
sub = '02'
ses = '02'
fname = T2s % (sub, ses, sub, ses)
fname
# Out:
# '/scratch/qbi/uqkgarn1/STRIWP1/derivatives/sub-02/ses-02/func/sub-02_ses-02_task-learnAtt_acq-TR700_space-T1w_desc-preproc_bold.nii'

# %%
T2_img = nib.load(T2s)

# %%
T2_img.shape
# Out:
# (71, 92, 69)

# %%
data = T2_img.get_data()
# Out:
# /opt/miniconda-latest/envs/neuro/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   """Entry point for launching an IPython kernel.

# %%
tmp_data = data[:,:,:,0:-1]

# %%
np.shape(tmp_data)
# Out:
# (71, 89, 71, 915)

# %%
nu_img = nib.Nifti1Image(tmp_data, T2_img.affine, T2_img.header)

# %%
nib.save(nu_img, '/scratch/qbi/uqkgarn1/STRIWP1/derivatives/sub-05/ses-03/func/sub-05_ses-03_task-learnAtt_acq-TR700_echo-2_space-T1w_desc-preproc_bold.nii.gz')

# %% [markdown]
# ## Check dimensionality of thresholded t-images

# %%
timg = nib.load('/scratch/qbi/uqkgarn1/STRIWP1/derivatives/glmTDFAST/sub-02/TR700/THRSH/thrFEF_spmT_0001.nii.gz')

# %%
timg.shape
