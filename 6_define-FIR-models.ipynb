# %% [markdown]
# # Run FIR model on pared down GLM

# %%
from bids.layout import BIDSLayout
from nipype.interfaces import afni 
from nipype.interfaces.io import BIDSDataGrabber, DataFinder, DataSink, DataGrabber
import nipype.pipeline as pe
import nipype as ni
from nipype.interfaces.utility import Function
import nipype.interfaces.fsl.maths as fsl
from nipype.interfaces import spm as spm
from nipype.algorithms import modelgen as mgen
from nipype.algorithms.misc import Gunzip 
import pandas as pd
import os, re, json
import nipype.utils.filemanip as fm
# https://nipype.readthedocs.io/en/0.11.0/users/spmmcr.html
#
# set spm path to copy with use edit of spm_fMRI_design.m [see: https://www.jiscmail.ac.uk/cgi-bin/webadmin?A2=spm;f525092b.1508]
# scratch/qbi/uqkgarn1
matlab_cmd = '/scratch/qbi/uqkgarn1/spm12-r7219/run_spm12.sh /opt/matlabmcr-2010a/v713/ script'
spm.SPMCommand.set_mlab_paths(matlab_cmd=matlab_cmd, use_mcr=True)
# Out:
# 210309-13:17:02,775 nipype.utils WARNING:
# 	 A newer version (1.5.1) of nipy/nipype is available. You are using 1.5.0

# %%
Basedir = "/scratch/qbi/uqkgarn1/STRIWP1/"
layout = BIDSLayout(Basedir)
subs = layout.get_subjects()

firs = pe.Workflow(name="firs") # workflow to run the analysis
# Out:
# /opt/miniconda-latest/envs/neuro/lib/python3.6/site-packages/bids/layout/models.py:102: FutureWarning: The 'extension' entity currently excludes the leading dot ('.'). As of version 0.14.0, it will include the leading dot. To suppress this warning and include the leading dot, use `bids.config.set_option('extension_initial_dot', True)`.
#   FutureWarning)

# %% [markdown]
# # grab and sink data

# %%
dgT2s = pe.Node(DataGrabber(infields=['sub', 'TR'], 
                            outfields=['func','motion','onsets','bjson','mask']), name='T2-grabber')
dgT2s.inputs.base_dir = "/scratch/qbi/uqkgarn1/STRIWP1/"
dgT2s.inputs.sort_filelist = True
dgT2s.inputs.template='*'
dgT2s.inputs.template_args = {'func': [['sub', 'sub', 'TR']],
                              'motion':[['sub', 'sub', 'TR']],
                              'onsets':[['sub', 'sub', 'TR']],
                              'bjson':[['sub', 'sub', 'TR']],
                              'mask':[['sub', 'sub', 'TR']]}
dgT2s.inputs.field_template = {'func': '/scratch/qbi/uqkgarn1/STRIWP1/derivatives/sub-%s/ses-*/func/sub-%s_*TR%s_space-T1w_desc-preproc_bold.nii.gz',
                               'motion': '/scratch/qbi/uqkgarn1/STRIWP1/derivatives/glm/sub-%s/ses-*/func/sub-%s_*-TR%s*desc-motion_regressors.txt',
                               'onsets': '/scratch/qbi/uqkgarn1/STRIWP1/derivatives/sub-%s/ses-*/func/sub-%s_*-TR%s_glm_onsets.json',
                               'bjson': '/scratch/qbi/uqkgarn1/STRIWP1/derivatives/sub-%s/ses-*/func/sub-%s_*-TR%s*space-T1w_desc-preproc_bold.json',
                               'mask': '/scratch/qbi/uqkgarn1/STRIWP1/derivatives/sub-%s/ses-02/func/sub-%s_*TR%s_space-T1w_desc-brain_mask.nii.gz'}

# %%
# # debugging
# dgT2s.inputs.sub = '01'
# dgT2s.inputs.TR = '1510'
# res = dgT2s.run()
# res.outputs

# %%
T2inf = pe.Node(ni.IdentityInterface(fields=['sub', 'TR']),
                   name='T2-info')
T2inf.iterables = [('sub', ['01', '02', '03', '04', '05']), ('TR', ['700', '1510', '1920'])]
#T2inf.iterables = [('sub', ['01']), ('TR', ['700', '1510', '1920'])]
T2inf.iterables
# Out:
# [('sub', ['01', '02', '03', '04', '05']), ('TR', ['700', '1510', '1920'])]

# %%
def printSubPath(fullFilePath):
    # function to split filepath into constituent parts, then print string to add as input to DataSink for the container string
    # given the full filepath, this extracts the subject folder and TR strings for input
    # into DataSink
    import os
    import re
    fname = os.path.normpath(fullFilePath[0])
    fname
    l = fname.split(os.sep)
    TR = re.search('.*acq-TR([0-9]*)_.*',l[-1])
    TR = str(int(TR.group(1)))
    name = [s for s in l if re.search('sub', s)][0]
    name = [name, "TR"+TR]
    name
    name = '/'.join(name)
    return name

# %%
ds = pe.Node(DataSink(), name='sink-stuff')
ds.inputs.base_directory = "/scratch/qbi/uqkgarn1/STRIWP1/derivatives/glmFIR/"
substitutions = [('_TR_([0-9]*)_sub_([0-9]*)', '')]
ds.inputs.regexp_substitutions = substitutions

# %% [markdown]
# # design informatiano

# %% [markdown]
# #### Overall

# %%
# the input function should be a list of the prt files, taken across sessions, for each TR
def getOnsetsJson(input_files):
    from nipype.interfaces.base import Bunch
    import json
    prt_output = [] #prt=protocol
    count = 0
    for f in input_files: 
        count = count + 1
        with open(f, "r+") as file:
            data = json.load(file)
            prt_output.insert(count, 
                              Bunch(conditions=data['names'],
                                    onsets=data['onsets'],
                                    durations=data['durations']))
    return prt_output

# %%
getOnsets = pe.Node(Function(input_names=['input_files'],
                             output_names=['prt_output'],
                             function=getOnsetsJson),
                    name='get_prt_onsets')

# %% [markdown]
# #### Target onset

# %%
def nu_regressors_comb2(bunches, cond_a, cond_b, nunames):
    # Warning: some elements of this function are hard coded!
    # this function will take a prt output (attained from getOnsets node),
    # and will collapse the conditions listed in cond_a, and those listed in cond_b
    # and will make 2 new conditions, labelled nunames
    from nipype.interfaces.base import Bunch
    nu_output = []
    count = 0
    for bunch in bunches:
        count = count + 1
    
        idx_a = [i for i,c in enumerate(bunch.conditions) if c in cond_a]
        idx_b = [i for i,c in enumerate(bunch.conditions) if c in cond_b]
        nuonsets = [[o  for i in idx_a for o in bunch.onsets[i]],
                    [o  for i in idx_b for o in bunch.onsets[i]]]
        nu_output.insert(count, 
                         Bunch(conditions=nunames,
                               onsets=nuonsets,
                               durations=[[0],[0]]))
    return nu_output

# %%
collapseOnsets = pe.Node(Function(input_names=['bunches', 'cond_a', 'cond_b', 'nunames'],
                                  output_names=['nu_output'],
                                  function=nu_regressors_comb2),
                        name='collapseOnsets')
collapseOnsets.inputs.cond_a = ['att_left_5', 'att_left_8']
collapseOnsets.inputs.cond_b = ['att_right_5', 'att_right_8']
collapseOnsets.inputs.nunames = ['tgt_left', 'tgt_right']

# %% [markdown]
# #### response hand

# %%
def select_regressors(bunches, conditions):
    # this function allows you to isolate the regressors that match the list of conditions, 
    # and returns them in the prt format for spm12
    from nipype.interfaces.base import Bunch
    nu_output = []
    count = 0
    
    for bunch in bunches:
        count = count + 1
        idx = [i for i,c in enumerate(bunch.conditions) if c in conditions]
        nuonsets = []
        nudurs = []
        for i in idx:
            nuonsets.append(bunch.onsets[i])
            nudurs.append([0])
            
        nu_output.insert(count, 
                         Bunch(conditions=conditions,
                               onsets=nuonsets,
                               durations=nudurs))
    return nu_output

# %%
selectOnsets = pe.Node(Function(input_names=['bunches', 'conditions'],
                                output_names=['nu_output'],
                                function=select_regressors),
                        name='selectOnsets')
selectOnsets.inputs.conditions = ['left_hand', 'right_hand']

# %% [markdown]
# # Gunzip nodes

# %%
gunzipfunc = pe.MapNode(Gunzip(), name='gunzipfunc', iterfield=['in_file'])

# %%
gmask = pe.Node(Gunzip(), name='m-zip')

# %% [markdown]
# # Get the TR for the model spec

# %%
# the input function should be a list of the prt files, taken across sessions, for each TR
def getTRJson(input_files):
    import json
    with open(input_files[0], "r+") as file:
            data = json.load(file)
            TR = data['RepetitionTime'] 
    if TR < .5:
        TR = 1.92
    return TR

# %%
getTR = pe.Node(Function(input_names=['input_files'],
                         output_names=['TR'],
                         function=getTRJson),
                name='get_TR')

# %%
def printSavFol(TR):
    # function to append the TR to a name for the save folder
    name = "TR" + TR
    return name

# %% [markdown]
# # Specify GLM Model

# %%
# SpecifyModel - Generates SPM-specific Model
modelspec = pe.Node(mgen.SpecifySPMModel(concatenate_runs=False,
                                         input_units='secs',
                                         output_units='secs',
                                         high_pass_filter_cutoff=128),
                    name="modelspec")

# %% [markdown]
# # Generate design matrix

# %%
# Level1Design - Generates an SPM design matrix
level1design = pe.Node(spm.Level1Design(bases={'fir': {'length': 18,
                                                       'order': 9}},
                                 timing_units='secs',
                                 model_serial_correlations='FAST'),
                       name="level1design")

# %% [markdown]
# # Connect workflow (collapsed onsets)

# %%
firs.connect([(T2inf, dgT2s, [('sub',  'sub')]), 
              (T2inf, dgT2s, [('TR',   'TR')]),
              (dgT2s, ds, [(('motion', printSubPath),
                             'container')]),
              (dgT2s, getOnsets, [('onsets', 'input_files')]),
              (getOnsets, collapseOnsets, [('prt_output', 'bunches')]),
              (dgT2s, gunzipfunc, [('func', 'in_file')]),
              (dgT2s, gmask, [('mask', 'in_file')]),
              (dgT2s, getTR, [('bjson', 'input_files')]),
              
              (getTR, modelspec, [('TR', 'time_repetition')]),
              (dgT2s, modelspec, [('motion', 'realignment_parameters')]), 
              (collapseOnsets, modelspec, [('nu_output', 'subject_info')]),
              (gunzipfunc, modelspec, [('out_file', 'functional_runs')]),
              (getTR, level1design, [('TR', 'interscan_interval')]),
              (modelspec, level1design, [('session_info', 'session_info')]),
              (gmask, level1design, [('out_file', 'mask_image')]),
              (level1design, ds, [('spm_mat_file', 'FLGLM.@des')])
])

# %%
firs.run()
# Out:
# 210309-13:17:16,890 nipype.workflow INFO:
# 	 Workflow firs settings: ['check', 'execution', 'logging', 'monitoring']
# 210309-13:17:17,93 nipype.workflow INFO:
# 	 Running serially.
# 210309-13:17:17,95 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.T2-grabber" in "/tmp/tmp60xn_ssm/firs/_TR_1920_sub_05/T2-grabber".
# 210309-13:17:17,101 nipype.workflow INFO:
# 	 [Node] Running "T2-grabber" ("nipype.interfaces.io.DataGrabber")
# 210309-13:17:17,125 nipype.workflow INFO:
# 	 [Node] Finished "firs.T2-grabber".
# 210309-13:17:17,127 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.get_TR" in "/tmp/tmpgjsjewx2/firs/_TR_1920_sub_05/get_TR".
# 210309-13:17:17,132 nipype.workflow INFO:
# 	 [Node] Running "get_TR" ("nipype.interfaces.utility.wrappers.Function")
# 210309-13:17:17,137 nipype.workflow INFO:
# 	 [Node] Finished "firs.get_TR".
# 210309-13:17:17,137 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.m-zip" in "/tmp/tmpj_2_sgm0/firs/_TR_1920_sub_05/m-zip".
# 210309-13:17:17,141 nipype.workflow INFO:
# 	 [Node] Running "m-zip" ("nipype.algorithms.misc.Gunzip")
# 210309-13:17:17,171 nipype.workflow INFO:
# 	 [Node] Finished "firs.m-zip".
# 210309-13:17:17,172 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.gunzipfunc" in "/tmp/tmp0h_za0f6/firs/_TR_1920_sub_05/gunzipfunc".
# 210309-13:17:17,178 nipype.workflow INFO:
# 	 [Node] Setting-up "_gunzipfunc0" in "/tmp/tmp0h_za0f6/firs/_TR_1920_sub_05/gunzipfunc/mapflow/_gunzipfunc0".
# 210309-13:17:17,181 nipype.workflow INFO:
# 	 [Node] Running "_gunzipfunc0" ("nipype.algorithms.misc.Gunzip")
# 210309-13:17:23,766 nipype.workflow INFO:
# 	 [Node] Finished "_gunzipfunc0".
# 210309-13:17:23,768 nipype.workflow INFO:
# 	 [Node] Setting-up "_gunzipfunc1" in "/tmp/tmp0h_za0f6/firs/_TR_1920_sub_05/gunzipfunc/mapflow/_gunzipfunc1".
# 210309-13:17:23,772 nipype.workflow INFO:
# 	 [Node] Running "_gunzipfunc1" ("nipype.algorithms.misc.Gunzip")
# 210309-13:17:30,339 nipype.workflow INFO:
# 	 [Node] Finished "_gunzipfunc1".
# 210309-13:17:30,342 nipype.workflow INFO:
# 	 [Node] Setting-up "_gunzipfunc2" in "/tmp/tmp0h_za0f6/firs/_TR_1920_sub_05/gunzipfunc/mapflow/_gunzipfunc2".
# 210309-13:17:30,345 nipype.workflow INFO:
# 	 [Node] Running "_gunzipfunc2" ("nipype.algorithms.misc.Gunzip")
# 210309-13:17:37,28 nipype.workflow INFO:
# 	 [Node] Finished "_gunzipfunc2".
# 210309-13:17:37,36 nipype.workflow INFO:
# 	 [Node] Finished "firs.gunzipfunc".
# 210309-13:17:37,37 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.get_prt_onsets" in "/tmp/tmpzr109ypu/firs/_TR_1920_sub_05/get_prt_onsets".
# 210309-13:17:37,44 nipype.workflow INFO:
# 	 [Node] Running "get_prt_onsets" ("nipype.interfaces.utility.wrappers.Function")
# 210309-13:17:37,90 nipype.workflow INFO:
# 	 [Node] Finished "firs.get_prt_onsets".
# 210309-13:17:37,91 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.collapseOnsets" in "/tmp/tmp568rqu8x/firs/_TR_1920_sub_05/collapseOnsets".
# 210309-13:17:37,110 nipype.workflow INFO:
# 	 [Node] Running "collapseOnsets" ("nipype.interfaces.utility.wrappers.Function")
# 210309-13:17:37,119 nipype.workflow INFO:
# 	 [Node] Finished "firs.collapseOnsets".
# 210309-13:17:37,120 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.modelspec" in "/tmp/tmprfq7lxm0/firs/_TR_1920_sub_05/modelspec".
# 210309-13:17:37,134 nipype.workflow INFO:
# 	 [Node] Running "modelspec" ("nipype.algorithms.modelgen.SpecifySPMModel")
# 210309-13
nipype.workflow INFO:
# 	 [Node] Setting-up "firs.gunzipfunc" in "/tmp/tmpo8xbaraf/firs/_TR_700_sub_04/gunzipfunc".
# 210309-13:23:31,638 nipype.workflow INFO:
# 	 [Node] Setting-up "_gunzipfunc0" in "/tmp/tmpo8xbaraf/firs/_TR_700_sub_04/gunzipfunc/mapflow/_gunzipfunc0".
# 210309-13:23:31,641 nipype.workflow INFO:
# 	 [Node] Running "_gunzipfunc0" ("nipype.algorithms.misc.Gunzip")
# 210309-13:23:38,196 nipype.workflow INFO:
# 	 [Node] Finished "_gunzipfunc0".
# 210309-13:23:38,199 nipype.workflow INFO:
# 	 [Node] Setting-up "_gunzipfunc1" in "/tmp/tmpo8xbaraf/firs/_TR_700_sub_04/gunzipfunc/mapflow/_gunzipfunc1".
# 210309-13:23:38,203 nipype.workflow INFO:
# 	 [Node] Running "_gunzipfunc1" ("nipype.algorithms.misc.Gunzip")
# 210309-13:23:44,715 nipype.workflow INFO:
# 	 [Node] Finished "_gunzipfunc1".
# 210309-13:23:44,719 nipype.workflow INFO:
# 	 [Node] Setting-up "_gunzipfunc2" in "/tmp/tmpo8xbaraf/firs/_TR_700_sub_04/gunzipfunc/mapflow/_gunzipfunc2".
# 210309-13:23:44,724 nipype.workflow INFO:
# 	 [Node] Running "_gunzipfunc2" ("nipype.algorithms.misc.Gunzip")
# 210309-13:23:51,162 nipype.workflow INFO:
# 	 [Node] Finished "_gunzipfunc2".
# 210309-13:23:51,167 nipype.workflow INFO:
# 	 [Node] Finished "firs.gunzipfunc".
# 210309-13:23:51,168 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.get_prt_onsets" in "/tmp/tmp63f83_w8/firs/_TR_700_sub_04/get_prt_onsets".
# 210309-13:23:51,173 nipype.workflow INFO:
# 	 [Node] Running "get_prt_onsets" ("nipype.interfaces.utility.wrappers.Function")
# 210309-13:23:51,242 nipype.workflow INFO:
# 	 [Node] Finished "firs.get_prt_onsets".
# 210309-13:23:51,244 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.collapseOnsets" in "/tmp/tmpz9se8vj5/firs/_TR_700_sub_04/collapseOnsets".
# 210309-13:23:51,262 nipype.workflow INFO:
# 	 [Node] Running "collapseOnsets" ("nipype.interfaces.utility.wrappers.Function")
# 210309-13:23:51,270 nipype.workflow INFO:
# 	 [Node] Finished "firs.collapseOnsets".
# 210309-13:23:51,270 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.modelspec" in "/tmp/tmpk42d0cn_/firs/_TR_700_sub_04/modelspec".
# 210309-13:23:51,285 nipype.workflow INFO:
# 	 [Node] Running "modelspec" ("nipype.algorithms.modelgen.SpecifySPMModel")
# 210309-13:23:51,686 nipype.workflow INFO:
# 	 [Node] Finished "firs.modelspec".
# 210309-13:23:51,688 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.level1design" in "/tmp/tmphpuk9n27/firs/_TR_700_sub_04/level1design".
# 210309-13:23:52,630 nipype.workflow INFO:
# 	 [Node] Running "level1design" ("nipype.interfaces.spm.model.Level1Design")
# 210309-13:25:00,167 nipype.workflow INFO:
# 	 [Node] Finished "firs.level1design".
# 210309-13:25:00,169 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.sink-stuff" in "/tmp/tmpbew9ch19/firs/_TR_700_sub_04/sink-stuff".
# 210309-13:25:00,181 nipype.workflow INFO:
# 	 [Node] Running "sink-stuff" ("nipype.interfaces.io.DataSink")
# 210309-13:25:00,183 nipype.interface INFO:
# 	 sub: /scratch/qbi/uqkgarn1/STRIWP1/derivatives/glmFIR/sub-04/TR700/FLGLM/_TR_700_sub_04/SPM.mat -> /scratch/qbi/uqkgarn1/STRIWP1/derivatives/glmFIR/sub-04/TR700/FLGLM//SPM.mat
# 210309-13:25:00,329 nipype.workflow INFO:
# 	 [Node] Finished "firs.sink-stuff".
# 210309-13:25:00,330 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.T2-grabber" in "/tmp/tmpj3908zse/firs/_TR_1920_sub_03/T2-grabber".
# 210309-13:25:00,335 nipype.workflow INFO:
# 	 [Node] Running "T2-grabber" ("nipype.interfaces.io.DataGrabber")
# 210309-13:25:00,358 nipype.workflow INFO:
# 	 [Node] Finished "firs.T2-grabber".
# 210309-13:25:00,358 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.get_TR" in "/tmp/tmpzq2a63si/firs/_TR_1920_sub_03/get_TR".
# 210309-13:25:00,363 nipype.workflow INFO:
# 	 [Node] Running "get_TR" ("nipype.interfaces.utility.wrappers.Function")
# 210309-13:25:00,367 nipype.workflow INFO:
# 	 [Node] Finished "firs.get_TR".
# 210309-13:25:00,368 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.m-zip" in "/tmp/tmpqfw4idye/firs/_TR_1920_sub_03/m-zip".
# 210309-13:25:00,372 nipype.workflow INFO:
# 	 [Node] Running "m-zip" ("nipype.algorithms.misc.Gunzip")
# 210309-13:25:00,411 nipype.workflow INFO:
# 	 [Node] Finished "firs.m-zip".
# 210309-13:25:00,412 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.gunzipfunc" in "/tmp/tmp0kzyrrdm/firs/_TR_1920_sub_03/gunzipfunc".
# 210309-13:25:00,418 nipype.workflow INFO:
# 	 [Node] Setting-up "_gunzipfunc0" in "/tmp/tmp0kzyrrdm/firs/_TR_1920_sub_03/gunzipfunc/mapflow/_gunzipfunc0".
# 210309-13:25:00,424 nipype.workflow INFO:
# 	 [Node] Running "_gunzipfunc0" ("nipype.algorithms.misc.Gunzip")
# 210309-13:25:08,31 nipype.workflow INFO:
# 	 [Node] Finished "_gunzipfunc0".
# 210309-13:25:08,34 nipype.workflow INFO:
# 	 [Node] Setting-up "_gunzipfunc1" in "/tmp/tmp0kzyrrdm/firs/_TR_1920_sub_03/gunzipfunc/mapflow/_gunzipfunc1".
# 210309-13:25:08,39 nipype.workflow INFO:
# 	 [Node] Running "_gunzipfunc1" ("nipype.algorithms.misc.Gunzip")
# 210309-13:25:15,38 nipype.workflow INFO:
# 	 [Node] Finished "_gunzipfunc1".
# 210309-13:25:15,42 nipype.workflow INFO:
# 	 [Node] Finished "firs.gunzipfunc".
# 210309-13:25:15,43 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.get_prt_onsets" in "/tmp/tmpdeghcenr/firs/_TR_1920_sub_03/get_prt_onsets".
# 210309-13:25:15,49 nipype.workflow INFO:
# 	 [Node] Running "get_prt_onsets" ("nipype.interfaces.utility.wrappers.Function")
# 210309-13:25:15,85 nipype.workflow INFO:
# 	 [Node] Finished "firs.get_prt_onsets".
# 210309-13:25:15,86 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.collapseOnsets" in "/tmp/tmpjoit5d89/firs/_TR_1920_sub_03/collapseOnsets".
# 210309-13:25:15,99 nipype.workflow INFO:
# 	 [Node] Running "collapseOnsets" ("nipype.interfaces.utility.wrappers.Function")
# 210309-13:25:15,106 nipype.workflow INFO:
# 	 [Node] Finished "firs.collapseOnsets".
# 210309-13:25:15,107 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.modelspec" in "/tmp/tmpp4nffk4t/firs/_TR_1920_sub_03/modelspec".
# 210309-13:25:15,120 nipype.workflow INFO:
# 	 [Node] Running "modelspec" ("nipype.algorithms.modelgen.SpecifySPMModel")
# 210309-13:25:15,278 nipype.workflow INFO:
# 	 [Node] Finished "firs.modelspec".
# 210309-13:25:15,279 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.level1design" in "/tmp/tmp05x_vpbt/firs/_TR_1920_sub_03/level1design".
# 210309-13:25:15,606 nipype.workflow INFO:
# 	 [Node] Running "level1design" ("nipype.interfaces.spm.model.Level1Design")
# 210309-13:25:48,693 nipype.workflow INFO:
# 	 [Node] Finished "firs.level1design".
# 210309-13:25:48,695 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.sink-stuff" in "/tmp/tmph_5ffntk/firs/_TR_1920_sub_03/sink-stuff".
# 210309-13:25:48,705 nipype.workflow INFO:
# 	 [Node] Running "sink-stuff" ("nipype.interfaces.io.DataSink")
# 210309-13:25:48,707 nipype.interface INFO:
# 	 sub: /scratch/qbi/uqkgarn1/STRIWP1/derivatives/glmFIR/sub-03/TR1920/FLGLM/_TR_1920_sub_03/SPM.mat -> /scratch/qbi/uqkgarn1/STRIWP1/derivatives/glmFIR/sub-03/TR1920/FLGLM//SPM.mat
# 210309-13:25:48,734 nipype.workflow INFO:
# 	 [Node] Finished "firs.sink-stuff".
# 210309-13:25:48,735 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.T2-grabber" in "/tmp/tmp_8k2khwp/firs/_TR_1510_sub_03/T2-grabber".
# 210309-13:25:48,741 nipype.workflow INFO:
# 	 [Node] Running "T2-grabber" ("nipype.interfaces.io.DataGrabber")
# 210309-13:25:48,757 nipype.workflow INFO:
# 	 [Node] Finished "firs.T2-grabber".
# 210309-13:25:48,758 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.get_TR" in "/tmp/tmp8y9ildw0/firs/_TR_1510_sub_03/get_TR".
# 210309-13:25:48,763 nipype.workflow INFO:
# 	 [Node] Running "get_TR" ("nipype.interfaces.utility.wrappers.Function")
# 210309-13:25:48,768 nipype.workflow INFO:
# 	 [Node] Finished "firs.get_TR".
# 210309-13:25:48,769 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.m-zip" in "/tmp/tmpn8wz6kve/firs/_TR_1510_sub_03/m-zip".
# 210309-13:25:48,774 nipype.workflow INFO:
# 	 [Node] Running "m-zip" ("nipype.algorithms.misc.Gunzip")
# 210309-13:25:48,819 nipype.workflow INFO:
# 	 [Node] Finished "firs.m-zip".
# 210309-13:25:48,820 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.gunzipfunc" in "/tmp/tmpqxk0ta0c/firs/_TR_1510_sub_03/gunzipfunc".
# 210309-13:25:48,826 nipype.workflow INFO:
# 	 [Node] Setting-up "_gunzipfunc0" in "/tmp/tmpqxk0ta0c/firs/_TR_1510_sub_03/gunzipfunc/mapflow/_gunzipfunc0".
# 210309-13:25:48,829 nipype.workflow INFO:
# 	 [Node] Running "_gunzipfunc0" ("nipype.algorithms.misc.Gunzip")
# 210309-13:25:58,149 nipype.workflow INFO:
# 	 [Node] Finished "_gunzipfunc0".
# 210309-13:25:58,151 nipype.workflow INFO:
# 	 [Node] Setting-up "_gunzipfunc1" in "/tmp/tmpqxk0ta0c/firs/_TR_1510_sub_03/gunzipfunc/mapflow/_gunzipfunc1".
# 210309-13:25:58,155 nipype.workflow INFO:
# 	 [Node] Running "_gunzipfunc1" ("nipype.algorithms.misc.Gunzip")
# 210309-13:26:07,275 nipype.workflow INFO:
# 	 [Node] Finished "_gunzipfunc1".
# 210309-13:26:07,278 nipype.workflow INFO:
# 	 [Node] Setting-up "_gunzipfunc2" in "/tmp/tmpqxk0ta0c/firs/_TR_1510_sub_03/gunzipfunc/mapflow/_gunzipfunc2".
# 210309-13:26:07,283 nipype.workflow INFO:
# 	 [Node] Running "_gunzipfunc2" ("nipype.algorithms.misc.Gunzip")
# 210309-13:26:16,449 nipype.workflow INFO:
# 	 [Node] Finished "_gunzipfunc2".
# 210309-13:26:16,453 nipype.workflow INFO:
# 	 [Node] Finished "firs.gunzipfunc".
# 210309-13:26:16,454 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.get_prt_onsets" in "/tmp/tmpsn6f2045/firs/_TR_1510_sub_03/get_prt_onsets".
# 210309-13:26:16,460 nipype.workflow INFO:
# 	 [Node] Running "get_prt_onsets" ("nipype.interfaces.utility.wrappers.Function")
# 210309-13:26:16,514 nipype.workflow INFO:
# 	 [Node] Finished "firs.get_prt_onsets".
# 210309-13:26:16,515 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.collapseOnsets" in "/tmp/t
nipype.workflow INFO:
# 	 [Node] Setting-up "firs.sink-stuff" in "/tmp/tmpeeu239x4/firs/_TR_1920_sub_02/sink-stuff".
# 210309-13:29:52,312 nipype.workflow INFO:
# 	 [Node] Running "sink-stuff" ("nipype.interfaces.io.DataSink")
# 210309-13:29:52,314 nipype.interface INFO:
# 	 sub: /scratch/qbi/uqkgarn1/STRIWP1/derivatives/glmFIR/sub-02/TR1920/FLGLM/_TR_1920_sub_02/SPM.mat -> /scratch/qbi/uqkgarn1/STRIWP1/derivatives/glmFIR/sub-02/TR1920/FLGLM//SPM.mat
# 210309-13:29:52,341 nipype.workflow INFO:
# 	 [Node] Finished "firs.sink-stuff".
# 210309-13:29:52,342 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.T2-grabber" in "/tmp/tmp9m9f79rz/firs/_TR_1510_sub_02/T2-grabber".
# 210309-13:29:52,348 nipype.workflow INFO:
# 	 [Node] Running "T2-grabber" ("nipype.interfaces.io.DataGrabber")
# 210309-13:29:52,362 nipype.workflow INFO:
# 	 [Node] Finished "firs.T2-grabber".
# 210309-13:29:52,363 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.get_TR" in "/tmp/tmpdxlnm3rk/firs/_TR_1510_sub_02/get_TR".
# 210309-13:29:52,368 nipype.workflow INFO:
# 	 [Node] Running "get_TR" ("nipype.interfaces.utility.wrappers.Function")
# 210309-13:29:52,372 nipype.workflow INFO:
# 	 [Node] Finished "firs.get_TR".
# 210309-13:29:52,373 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.m-zip" in "/tmp/tmpckkymrsg/firs/_TR_1510_sub_02/m-zip".
# 210309-13:29:52,378 nipype.workflow INFO:
# 	 [Node] Running "m-zip" ("nipype.algorithms.misc.Gunzip")
# 210309-13:29:52,413 nipype.workflow INFO:
# 	 [Node] Finished "firs.m-zip".
# 210309-13:29:52,415 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.gunzipfunc" in "/tmp/tmpjysa21_7/firs/_TR_1510_sub_02/gunzipfunc".
# 210309-13:29:52,420 nipype.workflow INFO:
# 	 [Node] Setting-up "_gunzipfunc0" in "/tmp/tmpjysa21_7/firs/_TR_1510_sub_02/gunzipfunc/mapflow/_gunzipfunc0".
# 210309-13:29:52,424 nipype.workflow INFO:
# 	 [Node] Running "_gunzipfunc0" ("nipype.algorithms.misc.Gunzip")
# 210309-13:30:02,653 nipype.workflow INFO:
# 	 [Node] Finished "_gunzipfunc0".
# 210309-13:30:02,656 nipype.workflow INFO:
# 	 [Node] Setting-up "_gunzipfunc1" in "/tmp/tmpjysa21_7/firs/_TR_1510_sub_02/gunzipfunc/mapflow/_gunzipfunc1".
# 210309-13:30:02,659 nipype.workflow INFO:
# 	 [Node] Running "_gunzipfunc1" ("nipype.algorithms.misc.Gunzip")
# 210309-13:30:12,352 nipype.workflow INFO:
# 	 [Node] Finished "_gunzipfunc1".
# 210309-13:30:12,356 nipype.workflow INFO:
# 	 [Node] Setting-up "_gunzipfunc2" in "/tmp/tmpjysa21_7/firs/_TR_1510_sub_02/gunzipfunc/mapflow/_gunzipfunc2".
# 210309-13:30:12,361 nipype.workflow INFO:
# 	 [Node] Running "_gunzipfunc2" ("nipype.algorithms.misc.Gunzip")
# 210309-13:30:22,98 nipype.workflow INFO:
# 	 [Node] Finished "_gunzipfunc2".
# 210309-13:30:22,103 nipype.workflow INFO:
# 	 [Node] Finished "firs.gunzipfunc".
# 210309-13:30:22,104 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.get_prt_onsets" in "/tmp/tmppwvmgz76/firs/_TR_1510_sub_02/get_prt_onsets".
# 210309-13:30:22,110 nipype.workflow INFO:
# 	 [Node] Running "get_prt_onsets" ("nipype.interfaces.utility.wrappers.Function")
# 210309-13:30:22,209 nipype.workflow INFO:
# 	 [Node] Finished "firs.get_prt_onsets".
# 210309-13:30:22,210 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.collapseOnsets" in "/tmp/tmpcvzpdw1c/firs/_TR_1510_sub_02/collapseOnsets".
# 210309-13:30:22,228 nipype.workflow INFO:
# 	 [Node] Running "collapseOnsets" ("nipype.interfaces.utility.wrappers.Function")
# 210309-13:30:22,235 nipype.workflow INFO:
# 	 [Node] Finished "firs.collapseOnsets".
# 210309-13:30:22,236 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.modelspec" in "/tmp/tmpy4slav3e/firs/_TR_1510_sub_02/modelspec".
# 210309-13:30:22,254 nipype.workflow INFO:
# 	 [Node] Running "modelspec" ("nipype.algorithms.modelgen.SpecifySPMModel")
# 210309-13:30:22,514 nipype.workflow INFO:
# 	 [Node] Finished "firs.modelspec".
# 210309-13:30:22,516 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.level1design" in "/tmp/tmp8iqh6jwy/firs/_TR_1510_sub_02/level1design".
# 210309-13:30:23,58 nipype.workflow INFO:
# 	 [Node] Running "level1design" ("nipype.interfaces.spm.model.Level1Design")
# 210309-13:31:20,990 nipype.workflow INFO:
# 	 [Node] Finished "firs.level1design".
# 210309-13:31:20,992 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.sink-stuff" in "/tmp/tmpn5fbpcg5/firs/_TR_1510_sub_02/sink-stuff".
# 210309-13:31:21,2 nipype.workflow INFO:
# 	 [Node] Running "sink-stuff" ("nipype.interfaces.io.DataSink")
# 210309-13:31:21,4 nipype.interface INFO:
# 	 sub: /scratch/qbi/uqkgarn1/STRIWP1/derivatives/glmFIR/sub-02/TR1510/FLGLM/_TR_1510_sub_02/SPM.mat -> /scratch/qbi/uqkgarn1/STRIWP1/derivatives/glmFIR/sub-02/TR1510/FLGLM//SPM.mat
# 210309-13:31:21,50 nipype.workflow INFO:
# 	 [Node] Finished "firs.sink-stuff".
# 210309-13:31:21,51 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.T2-grabber" in "/tmp/tmpfxv04su_/firs/_TR_700_sub_02/T2-grabber".
# 210309-13:31:21,57 nipype.workflow INFO:
# 	 [Node] Running "T2-grabber" ("nipype.interfaces.io.DataGrabber")
# 210309-13:31:21,76 nipype.workflow INFO:
# 	 [Node] Finished "firs.T2-grabber".
# 210309-13:31:21,77 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.get_TR" in "/tmp/tmp_kuzb3gy/firs/_TR_700_sub_02/get_TR".
# 210309-13:31:21,82 nipype.workflow INFO:
# 	 [Node] Running "get_TR" ("nipype.interfaces.utility.wrappers.Function")
# 210309-13:31:21,86 nipype.workflow INFO:
# 	 [Node] Finished "firs.get_TR".
# 210309-13:31:21,87 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.m-zip" in "/tmp/tmpt0mk4iry/firs/_TR_700_sub_02/m-zip".
# 210309-13:31:21,91 nipype.workflow INFO:
# 	 [Node] Running "m-zip" ("nipype.algorithms.misc.Gunzip")
# 210309-13:31:21,134 nipype.workflow INFO:
# 	 [Node] Finished "firs.m-zip".
# 210309-13:31:21,135 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.gunzipfunc" in "/tmp/tmpaoa8pwau/firs/_TR_700_sub_02/gunzipfunc".
# 210309-13:31:21,141 nipype.workflow INFO:
# 	 [Node] Setting-up "_gunzipfunc0" in "/tmp/tmpaoa8pwau/firs/_TR_700_sub_02/gunzipfunc/mapflow/_gunzipfunc0".
# 210309-13:31:21,144 nipype.workflow INFO:
# 	 [Node] Running "_gunzipfunc0" ("nipype.algorithms.misc.Gunzip")
# 210309-13:31:27,70 nipype.workflow INFO:
# 	 [Node] Finished "_gunzipfunc0".
# 210309-13:31:27,73 nipype.workflow INFO:
# 	 [Node] Setting-up "_gunzipfunc1" in "/tmp/tmpaoa8pwau/firs/_TR_700_sub_02/gunzipfunc/mapflow/_gunzipfunc1".
# 210309-13:31:27,77 nipype.workflow INFO:
# 	 [Node] Running "_gunzipfunc1" ("nipype.algorithms.misc.Gunzip")
# 210309-13:31:31,890 nipype.workflow INFO:
# 	 [Node] Finished "_gunzipfunc1".
# 210309-13:31:31,893 nipype.workflow INFO:
# 	 [Node] Setting-up "_gunzipfunc2" in "/tmp/tmpaoa8pwau/firs/_TR_700_sub_02/gunzipfunc/mapflow/_gunzipfunc2".
# 210309-13:31:31,897 nipype.workflow INFO:
# 	 [Node] Running "_gunzipfunc2" ("nipype.algorithms.misc.Gunzip")
# 210309-13:31:38,802 nipype.workflow INFO:
# 	 [Node] Finished "_gunzipfunc2".
# 210309-13:31:38,806 nipype.workflow INFO:
# 	 [Node] Finished "firs.gunzipfunc".
# 210309-13:31:38,807 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.get_prt_onsets" in "/tmp/tmp72fgfp8b/firs/_TR_700_sub_02/get_prt_onsets".
# 210309-13:31:38,813 nipype.workflow INFO:
# 	 [Node] Running "get_prt_onsets" ("nipype.interfaces.utility.wrappers.Function")
# 210309-13:31:38,885 nipype.workflow INFO:
# 	 [Node] Finished "firs.get_prt_onsets".
# 210309-13:31:38,886 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.collapseOnsets" in "/tmp/tmp2dwv7880/firs/_TR_700_sub_02/collapseOnsets".
# 210309-13:31:38,903 nipype.workflow INFO:
# 	 [Node] Running "collapseOnsets" ("nipype.interfaces.utility.wrappers.Function")
# 210309-13:31:38,911 nipype.workflow INFO:
# 	 [Node] Finished "firs.collapseOnsets".
# 210309-13:31:38,912 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.modelspec" in "/tmp/tmp4ny40_kh/firs/_TR_700_sub_02/modelspec".
# 210309-13:31:38,926 nipype.workflow INFO:
# 	 [Node] Running "modelspec" ("nipype.algorithms.modelgen.SpecifySPMModel")
# 210309-13:31:39,372 nipype.workflow INFO:
# 	 [Node] Finished "firs.modelspec".
# 210309-13:31:39,373 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.level1design" in "/tmp/tmpdgao6mvh/firs/_TR_700_sub_02/level1design".
# 210309-13:31:40,360 nipype.workflow INFO:
# 	 [Node] Running "level1design" ("nipype.interfaces.spm.model.Level1Design")
# 210309-13:32:48,693 nipype.workflow INFO:
# 	 [Node] Finished "firs.level1design".
# 210309-13:32:48,695 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.sink-stuff" in "/tmp/tmpijwkw_r_/firs/_TR_700_sub_02/sink-stuff".
# 210309-13:32:48,708 nipype.workflow INFO:
# 	 [Node] Running "sink-stuff" ("nipype.interfaces.io.DataSink")
# 210309-13:32:48,710 nipype.interface INFO:
# 	 sub: /scratch/qbi/uqkgarn1/STRIWP1/derivatives/glmFIR/sub-02/TR700/FLGLM/_TR_700_sub_02/SPM.mat -> /scratch/qbi/uqkgarn1/STRIWP1/derivatives/glmFIR/sub-02/TR700/FLGLM//SPM.mat
# 210309-13:32:48,864 nipype.workflow INFO:
# 	 [Node] Finished "firs.sink-stuff".
# 210309-13:32:48,865 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.T2-grabber" in "/tmp/tmp12hhchoq/firs/_TR_1920_sub_01/T2-grabber".
# 210309-13:32:48,871 nipype.workflow INFO:
# 	 [Node] Running "T2-grabber" ("nipype.interfaces.io.DataGrabber")
# 210309-13:32:48,880 nipype.workflow INFO:
# 	 [Node] Finished "firs.T2-grabber".
# 210309-13:32:48,881 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.get_TR" in "/tmp/tmp7ud6t6bm/firs/_TR_1920_sub_01/get_TR".
# 210309-13:32:48,886 nipype.workflow INFO:
# 	 [Node] Running "get_TR" ("nipype.interfaces.utility.wrappers.Function")
# 210309-13:32:48,891 nipype.workflow INFO:
# 	 [Node] Finished "firs.get_TR".
# 210309-13:32:48,892 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.m-zip" in "/tmp/tmpbajm5u_o/firs/_TR_1920_sub_01/m-zip".
# 210309-13:32:48,897 nipype.workflow INFO:
# 	 [Node] Running "m-zip" ("nipype.algorithms.misc.Gunzip")
# 210309-13:32:48,919 nipype.workflow INFO:
# 	 [Node] Finished "firs.m-zip".
# 210309-13:32:48,920 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.gunzipfunc" in "/tmp/tmpwed9vz94/firs/_TR_1920_sub_01/gunzipfunc".
# 210309-13:32:48,925 nipype.workflow INFO:
# 	 [Node] Setting-up "_gunzipfunc0" in "/tmp/tmpwed9vz94/firs/_TR_1920_sub_01/gunzipfunc/mapflow/_gunzipfunc0".
# 210309-13:32:48,929 nipype.workflow INFO:
# 	 [Node] Running "_gunzipfunc0" ("nipype.algorithms.misc.Gunzip")
# 210309-13:32:55,977 nipype.workflow INFO:
# 	 [Node] Finished "_gunzipfunc0".
# 210309-13:32:55,980 nipype.workflow INFO:
# 	 [Node] Setting-up "_gunzipfunc1" in "/tmp/tmpwed9vz94/firs/_TR_1920_sub_01/gunzipfunc/mapflow/_gunzipfunc1".
# 210309-13:32:55,985 nipype.workflow INFO:
# 	 [Node] Running "_gunzipfunc1" ("nipype.algorithms.misc.Gunzip")
# 210309-13:33:02,816 nipype.workflow INFO:
# 	 [Node] Finished "_gunzipfunc1".
# 210309-13:33:02,820 nipype.workflow INFO:
# 	 [Node] Finished "firs.gunzipfunc".
# 210309-13:33:02,821 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.get_prt_onsets" in "/tmp/tmpp4m49f60/firs/_TR_1920_sub_01/get_prt_onsets".
# 210309-13:33:02,826 nipype.workflow INFO:
# 	 [Node] Running "get_prt_onsets" ("nipype.interfaces.utility.wrappers.Function")
# 210309-13:33:02,833 nipype.workflow INFO:
# 	 [Node] Finished "firs.get_prt_onsets".
# 210309-13:33:02,834 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.collapseOnsets" in "/tmp/tmpzsjcq_ah/firs/_TR_1920_sub_01/collapseOnsets".
# 210309-13:33:02,846 nipype.workflow INFO:
# 	 [Node] Running "collapseOnsets" ("nipype.interfaces.utility.wrappers.Function")
# 210309-13:33:02,855 nipype.workflow INFO:
# 	 [Node] Finished "firs.collapseOnsets".
# 210309-13:33:02,856 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.modelspec" in "/tmp/tmpyqeb4zga/firs/_TR_1920_sub_01/modelspec".
# 210309-13:33:02,868 nipype.workflow INFO:
# 	 [Node] Running "modelspec" ("nipype.algorithms.modelgen.SpecifySPMModel")
# 210309-13:33:02,975 nipype.workflow INFO:
# 	 [Node] Finished "firs.modelspec".
# 210309-13:33:02,977 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.level1design" in "/tmp/tmpdghdi0a5/firs/_TR_1920_sub_01/level1design".
# 210309-13:33:03,272 nipype.workflow INFO:
# 	 [Node] Running "level1design" ("nipype.interfaces.spm.model.Level1Design")
# 210309-13:33:33,777 nipype.workflow INFO:
# 	 [Node] Finished "firs.level1design".
# 210309-13:33:33,779 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.sink-stuff" in "/tmp/tmp63zt6dpk/firs/_TR_1920_sub_01/sink-stuff".
# 210309-13:33:33,788 nipype.workflow INFO:
# 	 [Node] Running "sink-stuff" ("nipype.interfaces.io.DataSink")
# 210309-13:33:33,789 nipype.interface INFO:
# 	 sub: /scratch/qbi/uqkgarn1/STRIWP1/derivatives/glmFIR/sub-01/TR1920/FLGLM/_TR_1920_sub_01/SPM.mat -> /scratch/qbi/uqkgarn1/STRIWP1/derivatives/glmFIR/sub-01/TR1920/FLGLM//SPM.mat
# 210309-13:33:33,812 nipype.workflow INFO:
# 	 [Node] Finished "firs.sink-stuff".
# 210309-13:33:33,813 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.T2-grabber" in "/tmp/tmp09bl0at_/firs/_TR_1510_sub_01/T2-grabber".
# 210309-13:33:33,818 nipype.workflow INFO:
# 	 [Node] Running "T2-grabber" ("nipype.interfaces.io.DataGrabber")
# 210309-13:33:33,828 nipype.workflow INFO:
# 	 [Node] Finished "firs.T2-grabber".
# 210309-13:33:33,828 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.get_TR" in "/tmp/tmpdfbydtd8/firs/_TR_1510_sub_01/get_TR".
# 210309-13:33:33,833 nipype.workflow INFO:
# 	 [Node] Running "get_TR" ("nipype.interfaces.utility.wrappers.Function")
# 210309-13:33:33,837 nipype.workflow INFO:
# 	 [Node] Finished "firs.get_TR".
# 210309-13:33:33,838 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.m-zip" in "/tmp/tmprxvnakz5/firs/_TR_1510_sub_01/m-zip".
# 210309-13:33:33,842 nipype.workflow INFO:
# 	 [Node] Running "m-zip" ("nipype.algorithms.misc.Gunzip")
# 210309-13:33:33,863 nipype.workflow INFO:
# 	 [Node] Finished "firs.m-zip".
# 210309-13:33:33,864 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.gunzipfunc" in "/tmp/tmpdqmw_g6q/firs/_TR_1510_sub_01/gunzipfunc".
# 210309-13:33:33,870 nipype.workflow INFO:
# 	 [Node] Setting-up "_gunzipfunc0" in "/tmp/tmpdqmw_g6q/firs/_TR_1510_sub_01/gunzipfunc/mapflow/_gunzipfunc0".
# 210309-13:33:33,876 nipype.workflow INFO:
# 	 [Node] Running "_gunzipfunc0" ("nipype.algorithms.misc.Gunzip")
# 210309-13:33:42,869 nipype.workflow INFO:
# 	 [Node] Finished "_gunzipfunc0".
# 210309-13:33:42,872 nipype.workflow INFO:
# 	 [Node] Setting-up "_gunzipfunc1" in "/tmp/tmpdqmw_g6q/firs/_TR_1510_sub_01/gunzipfunc/mapflow/_gunzipfunc1".
# 210309-13:33:42,876 nipype.workflow INFO:
# 	 [Node] Running "_gunzipfunc1" ("nipype.algorithms.misc.Gunzip")
# 210309-13:33:51,348 nipype.workflow INFO:
# 	 [Node] Finished "_gunzipfunc1".
# 210309-13:33:51,352 nipype.workflow INFO:
# 	 [Node] Finished "firs.gunzipfunc".
# 210309-13:33:51,353 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.get_prt_onsets" in "/tmp/tmpp38cu3b3/firs/_TR_1510_sub_01/get_prt_onsets".
# 210309-13:33:51,359 nipype.workflow INFO:
# 	 [Node] Running "get_prt_onsets" ("nipype.interfaces.utility.wrappers.Function")
# 210309-13:33:51,365 nipype.workflow INFO:
# 	 [Node] Finished "firs.get_prt_onsets".
# 210309-13:33:51,366 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.collapseOnsets" in "/tmp/tmpn_zj6p2f/firs/_TR_1510_sub_01/collapseOnsets".
# 210309-13:33:51,378 nipype.workflow INFO:
# 	 [Node] Running "collapseOnsets" ("nipype.interfaces.utility.wrappers.Function")
# 210309-13:33:51,386 nipype.workflow INFO:
# 	 [Node] Finished "firs.collapseOnsets".
# 210309-13:33:51,387 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.modelspec" in "/tmp/tmp1kw3alqv/firs/_TR_1510_sub_01/modelspec".
# 210309-13:33:51,400 nipype.workflow INFO:
# 	 [Node] Running "modelspec" ("nipype.algorithms.modelgen.SpecifySPMModel")
# 210309-13:33:51,533 nipype.workflow INFO:
# 	 [Node] Finished "firs.modelspec".
# 210309-13:33:51,534 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.level1design" in "/tmp/tmpc0qk_e7k/firs/_TR_1510_sub_01/level1design".
# 210309-13:33:51,885 nipype.workflow INFO:
# 	 [Node] Running "level1design" ("nipype.interfaces.spm.model.Level1Design")
# 210309-13:34:28,452 nipype.workflow INFO:
# 	 [Node] Finished "firs.level1design".
# 210309-13:34:28,453 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.sink-stuff" in "/tmp/tmpnvfbh7hf/firs/_TR_1510_sub_01/sink-stuff".
# 210309-13:34:28,463 nipype.workflow INFO:
# 	 [Node] Running "sink-stuff" ("nipype.interfaces.io.DataSink")
# 210309-13:34:28,464 nipype.interface INFO:
# 	 sub: /scratch/qbi/uqkgarn1/STRIWP1/derivatives/glmFIR/sub-01/TR1510/FLGLM/_TR_1510_sub_01/SPM.mat -> /scratch/qbi/uqkgarn1/STRIWP1/derivatives/glmFIR/sub-01/TR1510/FLGLM//SPM.mat
# 210309-13:34:28,495 nipype.workflow INFO:
# 	 [Node] Finished "firs.sink-stuff".
# 210309-13:34:28,497 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.T2-grabber" in "/tmp/tmpmjx1u_3l/firs/_TR_700_sub_01/T2-grabber".
# 210309-13:34:28,502 nipype.workflow INFO:
# 	 [Node] Running "T2-grabber" ("nipype.interfaces.io.DataGrabber")
# 210309-13:34:28,511 nipype.workflow INFO:
# 	 [Node] Finished "firs.T2-grabber".
# 210309-13:34:28,512 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.get_TR" in "/tmp/tmpk5z6oh3_/firs/_TR_700_sub_01/get_TR".
# 210309-13:34:28,518 nipype.workflow INFO:
# 	 [Node] Running "get_TR" ("nipype.interfaces.utility.wrappers.Function")
# 210309-13:34:28,523 nipype.workflow INFO:
# 	 [Node] Finished "firs.get_TR".
# 210309-13:34:28,524 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.m-zip" in "/tmp/tmpfq68xwdr/firs/_TR_700_sub_01/m-zip".
# 210309-13:34:28,528 nipype.workflow INFO:
# 	 [Node] Running "m-zip" ("nipype.algorithms.misc.Gunzip")
# 210309-13:34:28,540 nipype.workflow INFO:
# 	 [Node] Finished "firs.m-zip".
# 210309-13:34:28,541 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.gunzipfunc" in "/tmp/tmp6329bp_b/firs/_TR_700_sub_01/gunzipfunc".
# 210309-13:34:28,546 nipype.workflow INFO:
# 	 [Node] Setting-up "_gunzipfunc0" in "/tmp/tmp6329bp_b/firs/_TR_700_sub_01/gunzipfunc/mapflow/_gunzipfunc0".
# 210309-13:34:28,549 nipype.workflow INFO:
# 	 [Node] Running "_gunzipfunc0" ("nipype.algorithms.misc.Gunzip")
# 210309-13:34:34,810 nipype.workflow INFO:
# 	 [Node] Finished "_gunzipfunc0".
# 210309-13:34:34,812 nipype.workflow INFO:
# 	 [Node] Setting-up "_gunzipfunc1" in "/tmp/tmp6329bp_b/firs/_TR_700_sub_01/gunzipfunc/mapflow/_gunzipfunc1".
# 210309-13:34:34,816 nipype.workflow INFO:
# 	 [Node] Running "_gunzipfunc1" ("nipype.algorithms.misc.Gunzip")
# 210309-13:34:41,420 nipype.workflow INFO:
# 	 [Node] Finished "_gunzipfunc1".
# 210309-13:34:41,424 nipype.workflow INFO:
# 	 [Node] Finished "firs.gunzipfunc".
# 210309-13:34:41,425 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.get_prt_onsets" in "/tmp/tmpo1twexys/firs/_TR_700_sub_01/get_prt_onsets".
# 210309-13:34:41,431 nipype.workflow INFO:
# 	 [Node] Running "get_prt_onsets" ("nipype.interfaces.utility.wrappers.Function")
# 210309-13:34:41,437 nipype.workflow INFO:
# 	 [Node] Finished "firs.get_prt_onsets".
# 210309-13:34:41,437 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.collapseOnsets" in "/tmp/tmpowa601x6/firs/_TR_700_sub_01/collapseOnsets".
# 210309-13:34:41,452 nipype.workflow INFO:
# 	 [Node] Running "collapseOnsets" ("nipype.interfaces.utility.wrappers.Function")
# 210309-13:34:41,458 nipype.workflow INFO:
# 	 [Node] Finished "firs.collapseOnsets".
# 210309-13:34:41,459 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.modelspec" in "/tmp/tmp72p1454y/firs/_TR_700_sub_01/modelspec".
# 210309-13:34:41,470 nipype.workflow INFO:
# 	 [Node] Running "modelspec" ("nipype.algorithms.modelgen.SpecifySPMModel")
# 210309-13:34:41,695 nipype.workflow INFO:
# 	 [Node] Finished "firs.modelspec".
# 210309-13:34:41,696 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.level1design" in "/tmp/tmp2hixyrbb/firs/_TR_700_sub_01/level1design".
# 210309-13:34:42,337 nipype.workflow INFO:
# 	 [Node] Running "level1design" ("nipype.interfaces.spm.model.Level1Design")
# 210309-13:35:35,894 nipype.workflow INFO:
# 	 [Node] Finished "firs.level1design".
# 210309-13:35:35,896 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.sink-stuff" in "/tmp/tmpu_8jth23/firs/_TR_700_sub_01/sink-stuff".
# 210309-13:35:35,907 nipype.workflow INFO:
# 	 [Node] Running "sink-stuff" ("nipype.interfaces.io.DataSink")
# 210309-13:35:35,909 nipype.interface INFO:
# 	 sub: /scratch/qbi/uqkgarn1/STRIWP1/derivatives/glmFIR/sub-01/TR700/FLGLM/_TR_700_sub_01/SPM.mat -> /scratch/qbi/uqkgarn1/STRIWP1/derivatives/glmFIR/sub-01/TR700/FLGLM//SPM.mat
# 210309-13:35:36,2 nipype.workflow INFO:
# 	 [Node] Finished "firs.sink-stuff".

# %% [markdown]
# At this point, the [regressors need to be de-orthogonalised (within condition)](https://www.jiscmail.ac.uk/cgi-bin/webadmin?A2=spm;f525092b.1508), so return to scratch and run the function redef_FIRs.m, prior to running notebook 9_run_FIR_models
