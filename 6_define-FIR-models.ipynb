# %% [markdown]
# # Run FIR model on pared down GLM

# %%
from bids.layout import BIDSLayout
from nipype.interfaces import afni 
from nipype.interfaces.io import BIDSDataGrabber, DataFinder, DataSink, DataGrabber
import nipype.pipeline as pe
import nipype as ni
from nipype.interfaces.utility import Function
import nipype.interfaces.fsl.maths as fsl
from nipype.interfaces import spm as spm
from nipype.algorithms import modelgen as mgen
from nipype.algorithms.misc import Gunzip 
import pandas as pd
import os, re, json
import nipype.utils.filemanip as fm
# https://nipype.readthedocs.io/en/0.11.0/users/spmmcr.html
#
# set spm path to copy with use edit of spm_fMRI_design.m [see: https://www.jiscmail.ac.uk/cgi-bin/webadmin?A2=spm;f525092b.1508]
# scratch/qbi/uqkgarn1
matlab_cmd = '/scratch/qbi/uqkgarn1/spm12-r7219/run_spm12.sh /opt/matlabmcr-2010a/v713/ script'
spm.SPMCommand.set_mlab_paths(matlab_cmd=matlab_cmd, use_mcr=True)

# %%
Basedir = "/scratch/qbi/uqkgarn1/STRIWP1/"
layout = BIDSLayout(Basedir)
subs = layout.get_subjects()

firs = pe.Workflow(name="firs") # workflow to run the analysis
# Out:
# /opt/miniconda-latest/envs/neuro/lib/python3.6/site-packages/bids/layout/models.py:102: FutureWarning: The 'extension' entity currently excludes the leading dot ('.'). As of version 0.14.0, it will include the leading dot. To suppress this warning and include the leading dot, use `bids.config.set_option('extension_initial_dot', True)`.
#   FutureWarning)

# %% [markdown]
# # grab and sink data

# %%
dgT2s = pe.Node(DataGrabber(infields=['sub', 'TR'], 
                            outfields=['func','motion','onsets','bjson','mask']), name='T2-grabber')
dgT2s.inputs.base_dir = "/scratch/qbi/uqkgarn1/STRIWP1/"
dgT2s.inputs.sort_filelist = True
dgT2s.inputs.template='*'
dgT2s.inputs.template_args = {'func': [['sub', 'sub', 'TR']],
                              'motion':[['sub', 'sub', 'TR']],
                              'onsets':[['sub', 'sub', 'TR']],
                              'bjson':[['sub', 'sub', 'TR']],
                              'mask':[['sub', 'sub', 'TR']]}
dgT2s.inputs.field_template = {'func': '/scratch/qbi/uqkgarn1/STRIWP1/derivatives/sub-%s/ses-*/func/sub-%s_*TR%s_space-T1w_desc-preproc_bold.nii.gz',
                               'motion': '/scratch/qbi/uqkgarn1/STRIWP1/derivatives/glm/sub-%s/ses-*/func/sub-%s_*-TR%s*desc-motion_regressors.txt',
                               'onsets': '/scratch/qbi/uqkgarn1/STRIWP1/derivatives/sub-%s/ses-*/func/sub-%s_*-TR%s_glm_onsets.json',
                               'bjson': '/scratch/qbi/uqkgarn1/STRIWP1/derivatives/sub-%s/ses-*/func/sub-%s_*-TR%s*space-T1w_desc-preproc_bold.json',
                               'mask': '/scratch/qbi/uqkgarn1/STRIWP1/derivatives/sub-%s/ses-02/func/sub-%s_*TR%s_space-T1w_desc-brain_mask.nii.gz'}

# %%
# # debugging
# dgT2s.inputs.sub = '01'
# dgT2s.inputs.TR = '1510'
# res = dgT2s.run()
# res.outputs

# %%
T2inf = pe.Node(ni.IdentityInterface(fields=['sub', 'TR']),
                   name='T2-info')
T2inf.iterables = [('sub', ['01', '02', '03', '04', '05']), ('TR', ['700', '1510', '1920'])]
#T2inf.iterables = [('sub', ['01']), ('TR', ['700', '1510', '1920'])]
T2inf.iterables
# Out:
# [('sub', ['01', '02', '03', '04', '05']), ('TR', ['700', '1510', '1920'])]

# %%
def printSubPath(fullFilePath):
    # function to split filepath into constituent parts, then print string to add as input to DataSink for the container string
    # given the full filepath, this extracts the subject folder and TR strings for input
    # into DataSink
    import os
    import re
    fname = os.path.normpath(fullFilePath[0])
    fname
    l = fname.split(os.sep)
    TR = re.search('.*acq-TR([0-9]*)_.*',l[-1])
    TR = str(int(TR.group(1)))
    name = [s for s in l if re.search('sub', s)][0]
    name = [name, "TR"+TR]
    name
    name = '/'.join(name)
    return name

# %%
ds = pe.Node(DataSink(), name='sink-stuff')
ds.inputs.base_directory = "/scratch/qbi/uqkgarn1/STRIWP1/derivatives/glmFIR/"
substitutions = [('_TR_([0-9]*)_sub_([0-9]*)', '')]
ds.inputs.regexp_substitutions = substitutions

# %% [markdown]
# # design informatiano

# %% [markdown]
# #### Overall

# %%
# the input function should be a list of the prt files, taken across sessions, for each TR
def getOnsetsJson(input_files):
    from nipype.interfaces.base import Bunch
    import json
    prt_output = [] #prt=protocol
    count = 0
    for f in input_files: 
        count = count + 1
        with open(f, "r+") as file:
            data = json.load(file)
            prt_output.insert(count, 
                              Bunch(conditions=data['names'],
                                    onsets=data['onsets'],
                                    durations=data['durations']))
    return prt_output

# %%
getOnsets = pe.Node(Function(input_names=['input_files'],
                             output_names=['prt_output'],
                             function=getOnsetsJson),
                    name='get_prt_onsets')

# %% [markdown]
# #### Target onset

# %%
def nu_regressors_comb2(bunches, cond_a, cond_b, nunames):
    # Warning: some elements of this function are hard coded!
    # this function will take a prt output (attained from getOnsets node),
    # and will collapse the conditions listed in cond_a, and those listed in cond_b
    # and will make 2 new conditions, labelled nunames
    from nipype.interfaces.base import Bunch
    nu_output = []
    count = 0
    for bunch in bunches:
        count = count + 1
    
        idx_a = [i for i,c in enumerate(bunch.conditions) if c in cond_a]
        idx_b = [i for i,c in enumerate(bunch.conditions) if c in cond_b]
        nuonsets = [[o  for i in idx_a for o in bunch.onsets[i]],
                    [o  for i in idx_b for o in bunch.onsets[i]]]
        nu_output.insert(count, 
                         Bunch(conditions=nunames,
                               onsets=nuonsets,
                               durations=[[0],[0]]))
    return nu_output

# %%
collapseOnsets = pe.Node(Function(input_names=['bunches', 'cond_a', 'cond_b', 'nunames'],
                                  output_names=['nu_output'],
                                  function=nu_regressors_comb2),
                        name='collapseOnsets')
collapseOnsets.inputs.cond_a = ['att_left_5', 'att_left_8']
collapseOnsets.inputs.cond_b = ['att_right_5', 'att_right_8']
collapseOnsets.inputs.nunames = ['tgt_left', 'tgt_right']

# %% [markdown]
# #### response hand

# %%
def select_regressors(bunches, conditions):
    # this function allows you to isolate the regressors that match the list of conditions, 
    # and returns them in the prt format for spm12
    from nipype.interfaces.base import Bunch
    nu_output = []
    count = 0
    
    for bunch in bunches:
        count = count + 1
        idx = [i for i,c in enumerate(bunch.conditions) if c in conditions]
        nuonsets = []
        nudurs = []
        for i in idx:
            nuonsets.append(bunch.onsets[i])
            nudurs.append([0])
            
        nu_output.insert(count, 
                         Bunch(conditions=conditions,
                               onsets=nuonsets,
                               durations=nudurs))
    return nu_output

# %%
selectOnsets = pe.Node(Function(input_names=['bunches', 'conditions'],
                                output_names=['nu_output'],
                                function=select_regressors),
                        name='selectOnsets')
selectOnsets.inputs.conditions = ['left_hand', 'right_hand']

# %% [markdown]
# # Gunzip nodes

# %%
gunzipfunc = pe.MapNode(Gunzip(), name='gunzipfunc', iterfield=['in_file'])

# %%
gmask = pe.Node(Gunzip(), name='m-zip')

# %% [markdown]
# # Get the TR for the model spec

# %%
# the input function should be a list of the prt files, taken across sessions, for each TR
def getTRJson(input_files):
    import json
    with open(input_files[0], "r+") as file:
            data = json.load(file)
            TR = data['RepetitionTime'] 
    if TR < .5:
        TR = 1.92
    return TR

# %%
getTR = pe.Node(Function(input_names=['input_files'],
                         output_names=['TR'],
                         function=getTRJson),
                name='get_TR')

# %%
def printSavFol(TR):
    # function to append the TR to a name for the save folder
    name = "TR" + TR
    return name

# %% [markdown]
# # Specify GLM Model

# %%
# SpecifyModel - Generates SPM-specific Model
modelspec = pe.Node(mgen.SpecifySPMModel(concatenate_runs=False,
                                         input_units='secs',
                                         output_units='secs',
                                         high_pass_filter_cutoff=128),
                    name="modelspec")

# %% [markdown]
# # Generate design matrix

# %%
# Level1Design - Generates an SPM design matrix
level1design = pe.Node(spm.Level1Design(bases={'fir': {'length': 18,
                                                       'order': 9}},
                                 timing_units='secs',
                                 model_serial_correlations='FAST'),
                       name="level1design")

# %% [markdown]
# # Connect workflow (collapsed onsets)

# %%
firs.connect([(T2inf, dgT2s, [('sub',  'sub')]), 
              (T2inf, dgT2s, [('TR',   'TR')]),
              (dgT2s, ds, [(('motion', printSubPath),
                             'container')]),
              (dgT2s, getOnsets, [('onsets', 'input_files')]),
              (getOnsets, selectOnsets, [('prt_output', 'bunches')]),
              (dgT2s, gunzipfunc, [('func', 'in_file')]),
              (dgT2s, gmask, [('mask', 'in_file')]),
              (dgT2s, getTR, [('bjson', 'input_files')]),
              
              (getTR, modelspec, [('TR', 'time_repetition')]),
              (dgT2s, modelspec, [('motion', 'realignment_parameters')]), 
              (selectOnsets, modelspec, [('nu_output', 'subject_info')]),
              (gunzipfunc, modelspec, [('out_file', 'functional_runs')]),
              (getTR, level1design, [('TR', 'interscan_interval')]),
              (modelspec, level1design, [('session_info', 'session_info')]),
              (gmask, level1design, [('out_file', 'mask_image')]),
              (level1design, ds, [('spm_mat_file', 'FLGLM.@des')])
])

# %%
firs.run()
# Out:
# 210522-18:17:35,826 nipype.workflow INFO:
# 	 Workflow firs settings: ['check', 'execution', 'logging', 'monitoring']
# 210522-18:17:36,28 nipype.workflow INFO:
# 	 Running serially.
# 210522-18:17:36,30 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.T2-grabber" in "/tmp/tmp8cm5zwvs/firs/_TR_1920_sub_05/T2-grabber".
# 210522-18:17:36,35 nipype.workflow INFO:
# 	 [Node] Running "T2-grabber" ("nipype.interfaces.io.DataGrabber")
# 210522-18:17:36,46 nipype.workflow INFO:
# 	 [Node] Finished "firs.T2-grabber".
# 210522-18:17:36,47 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.get_TR" in "/tmp/tmpzngdh_hc/firs/_TR_1920_sub_05/get_TR".
# 210522-18:17:36,51 nipype.workflow INFO:
# 	 [Node] Running "get_TR" ("nipype.interfaces.utility.wrappers.Function")
# 210522-18:17:36,56 nipype.workflow INFO:
# 	 [Node] Finished "firs.get_TR".
# 210522-18:17:36,56 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.m-zip" in "/tmp/tmpj3pgu18i/firs/_TR_1920_sub_05/m-zip".
# 210522-18:17:36,61 nipype.workflow INFO:
# 	 [Node] Running "m-zip" ("nipype.algorithms.misc.Gunzip")
# 210522-18:17:36,79 nipype.workflow INFO:
# 	 [Node] Finished "firs.m-zip".
# 210522-18:17:36,80 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.gunzipfunc" in "/tmp/tmpxa9htehm/firs/_TR_1920_sub_05/gunzipfunc".
# 210522-18:17:36,85 nipype.workflow INFO:
# 	 [Node] Setting-up "_gunzipfunc0" in "/tmp/tmpxa9htehm/firs/_TR_1920_sub_05/gunzipfunc/mapflow/_gunzipfunc0".
# 210522-18:17:36,89 nipype.workflow INFO:
# 	 [Node] Running "_gunzipfunc0" ("nipype.algorithms.misc.Gunzip")
# 210522-18:17:41,916 nipype.workflow INFO:
# 	 [Node] Finished "_gunzipfunc0".
# 210522-18:17:41,918 nipype.workflow INFO:
# 	 [Node] Setting-up "_gunzipfunc1" in "/tmp/tmpxa9htehm/firs/_TR_1920_sub_05/gunzipfunc/mapflow/_gunzipfunc1".
# 210522-18:17:41,922 nipype.workflow INFO:
# 	 [Node] Running "_gunzipfunc1" ("nipype.algorithms.misc.Gunzip")
# 210522-18:17:47,735 nipype.workflow INFO:
# 	 [Node] Finished "_gunzipfunc1".
# 210522-18:17:47,738 nipype.workflow INFO:
# 	 [Node] Setting-up "_gunzipfunc2" in "/tmp/tmpxa9htehm/firs/_TR_1920_sub_05/gunzipfunc/mapflow/_gunzipfunc2".
# 210522-18:17:47,741 nipype.workflow INFO:
# 	 [Node] Running "_gunzipfunc2" ("nipype.algorithms.misc.Gunzip")
# 210522-18:17:53,599 nipype.workflow INFO:
# 	 [Node] Finished "_gunzipfunc2".
# 210522-18:17:53,603 nipype.workflow INFO:
# 	 [Node] Finished "firs.gunzipfunc".
# 210522-18:17:53,604 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.get_prt_onsets" in "/tmp/tmph5ark_z5/firs/_TR_1920_sub_05/get_prt_onsets".
# 210522-18:17:53,610 nipype.workflow INFO:
# 	 [Node] Running "get_prt_onsets" ("nipype.interfaces.utility.wrappers.Function")
# 210522-18:17:53,616 nipype.workflow INFO:
# 	 [Node] Finished "firs.get_prt_onsets".
# 210522-18:17:53,617 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.selectOnsets" in "/tmp/tmp8qtpctrl/firs/_TR_1920_sub_05/selectOnsets".
# 210522-18:17:53,632 nipype.workflow INFO:
# 	 [Node] Running "selectOnsets" ("nipype.interfaces.utility.wrappers.Function")
# 210522-18:17:53,638 nipype.workflow INFO:
# 	 [Node] Finished "firs.selectOnsets".
# 210522-18:17:53,639 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.modelspec" in "/tmp/tmp3ly3lguu/firs/_TR_1920_sub_05/modelspec".
# 210522-18:17:53,653 nipype.workflow INFO:
# 	 [Node] Running "modelspec" ("nipype.algorithms.modelgen.SpecifySPMModel")
# 210522-18:17:53,790 nipype.workflow INFO:
# 	 [Node] Finished "firs.modelspec".
# 210522-18:17:53,791 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.level1design" in "/tmp/tmpfbzpdebz/firs/_TR_1920_sub_05/level1design".
# 210522-18:17:54,160 nipype.workflow INFO:
# 	 [Node] Running "level1design" ("nipype.interfaces.spm.model.Level1Design")
# 210522-18:18:33,321 nipype.workflow INFO:
# 	 [Node] Finished "firs.level1design".
# 210522-18:18:33,323 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.sink-stuff" in "/tmp/tmphdpz0v2e/firs/_TR_1920_sub_05/sink-stuff".
# 210522-18:18:33,334 nipype.workflow INFO:
# 	 [Node] Running "sink-stuff" ("nipype.interfaces.io.DataSink")
# 210522-18:18:33,336 nipype.interface INFO:
# 	 sub: /scratch/qbi/uqkgarn1/STRIWP1/derivatives/glmFIR/sub-05/TR1920/FLGLM/_TR_1920_sub_05/SPM.mat -> /scratch/qbi/uqkgarn1/STRIWP1/derivatives/glmFIR/sub-05/TR1920/FLGLM//SPM.mat
# 210522-18:18:33,364 nipype.workflow INFO:
# 	 [Node] Finished "firs.sink-stuff".
# 210522-18:18:33,365 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.T2-grabber" in "/tmp/tmpxmrm77hu/firs/_TR_1510_sub_05/T2-grabber".
# 210522-18:18:33,371 nipype.workflow INFO:
# 	 [Node] Running "T2-grabber" ("nipype.interfaces.io.DataGrabber")
# 210522-18:18:33,382 nipype.workflow INFO:
# 	 [Node] Finished "firs.T2-grabber".
# 210522-18:18:33,383 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.get_TR" in "/tmp/tmpc8geb21g/firs/_TR_1510_sub_05/get_TR".
# 210522-18:18:33,388 nipype.workflow INFO:
# 	 [Node] Running "get_TR" ("nipype.interfaces.utility.wrappers.Function")
# 210522-18:18:33,392 nipype.workflow INFO:
# 	 [Node] Finished "firs.get_TR".
# 210522-18
nipype.workflow INFO:
# 	 [Node] Setting-up "firs.get_prt_onsets" in "/tmp/tmppnvp4ppu/firs/_TR_1510_sub_02/get_prt_onsets".
# 210522-18:29:02,945 nipype.workflow INFO:
# 	 [Node] Running "get_prt_onsets" ("nipype.interfaces.utility.wrappers.Function")
# 210522-18:29:02,952 nipype.workflow INFO:
# 	 [Node] Finished "firs.get_prt_onsets".
# 210522-18:29:02,953 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.selectOnsets" in "/tmp/tmpu3djq2o0/firs/_TR_1510_sub_02/selectOnsets".
# 210522-18:29:02,969 nipype.workflow INFO:
# 	 [Node] Running "selectOnsets" ("nipype.interfaces.utility.wrappers.Function")
# 210522-18:29:02,977 nipype.workflow INFO:
# 	 [Node] Finished "firs.selectOnsets".
# 210522-18:29:02,977 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.modelspec" in "/tmp/tmp_y3ulhr0/firs/_TR_1510_sub_02/modelspec".
# 210522-18:29:02,992 nipype.workflow INFO:
# 	 [Node] Running "modelspec" ("nipype.algorithms.modelgen.SpecifySPMModel")
# 210522-18:29:03,182 nipype.workflow INFO:
# 	 [Node] Finished "firs.modelspec".
# 210522-18:29:03,183 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.level1design" in "/tmp/tmpcjgjgcnn/firs/_TR_1510_sub_02/level1design".
# 210522-18:29:03,718 nipype.workflow INFO:
# 	 [Node] Running "level1design" ("nipype.interfaces.spm.model.Level1Design")
# 210522-18:29:52,932 nipype.workflow INFO:
# 	 [Node] Finished "firs.level1design".
# 210522-18:29:52,933 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.sink-stuff" in "/tmp/tmps2n5y5y6/firs/_TR_1510_sub_02/sink-stuff".
# 210522-18:29:52,944 nipype.workflow INFO:
# 	 [Node] Running "sink-stuff" ("nipype.interfaces.io.DataSink")
# 210522-18:29:52,947 nipype.interface INFO:
# 	 sub: /scratch/qbi/uqkgarn1/STRIWP1/derivatives/glmFIR/sub-02/TR1510/FLGLM/_TR_1510_sub_02/SPM.mat -> /scratch/qbi/uqkgarn1/STRIWP1/derivatives/glmFIR/sub-02/TR1510/FLGLM//SPM.mat
# 210522-18:29:52,993 nipype.workflow INFO:
# 	 [Node] Finished "firs.sink-stuff".
# 210522-18:29:52,994 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.T2-grabber" in "/tmp/tmp7yfarane/firs/_TR_700_sub_02/T2-grabber".
# 210522-18:29:52,999 nipype.workflow INFO:
# 	 [Node] Running "T2-grabber" ("nipype.interfaces.io.DataGrabber")
# 210522-18:29:53,11 nipype.workflow INFO:
# 	 [Node] Finished "firs.T2-grabber".
# 210522-18:29:53,11 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.get_TR" in "/tmp/tmp932cx627/firs/_TR_700_sub_02/get_TR".
# 210522-18:29:53,17 nipype.workflow INFO:
# 	 [Node] Running "get_TR" ("nipype.interfaces.utility.wrappers.Function")
# 210522-18:29:53,21 nipype.workflow INFO:
# 	 [Node] Finished "firs.get_TR".
# 210522-18:29:53,22 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.m-zip" in "/tmp/tmp4nnbvjiu/firs/_TR_700_sub_02/m-zip".
# 210522-18:29:53,26 nipype.workflow INFO:
# 	 [Node] Running "m-zip" ("nipype.algorithms.misc.Gunzip")
# 210522-18:29:53,38 nipype.workflow INFO:
# 	 [Node] Finished "firs.m-zip".
# 210522-18:29:53,39 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.gunzipfunc" in "/tmp/tmpji39hsd_/firs/_TR_700_sub_02/gunzipfunc".
# 210522-18:29:53,44 nipype.workflow INFO:
# 	 [Node] Setting-up "_gunzipfunc0" in "/tmp/tmpji39hsd_/firs/_TR_700_sub_02/gunzipfunc/mapflow/_gunzipfunc0".
# 210522-18:29:53,47 nipype.workflow INFO:
# 	 [Node] Running "_gunzipfunc0" ("nipype.algorithms.misc.Gunzip")
# 210522-18:29:58,484 nipype.workflow INFO:
# 	 [Node] Finished "_gunzipfunc0".
# 210522-18:29:58,487 nipype.workflow INFO:
# 	 [Node] Setting-up "_gunzipfunc1" in "/tmp/tmpji39hsd_/firs/_TR_700_sub_02/gunzipfunc/mapflow/_gunzipfunc1".
# 210522-18:29:58,491 nipype.workflow INFO:
# 	 [Node] Running "_gunzipfunc1" ("nipype.algorithms.misc.Gunzip")
# 210522-18:30:02,781 nipype.workflow INFO:
# 	 [Node] Finished "_gunzipfunc1".
# 210522-18:30:02,783 nipype.workflow INFO:
# 	 [Node] Setting-up "_gunzipfunc2" in "/tmp/tmpji39hsd_/firs/_TR_700_sub_02/gunzipfunc/mapflow/_gunzipfunc2".
# 210522-18:30:02,787 nipype.workflow INFO:
# 	 [Node] Running "_gunzipfunc2" ("nipype.algorithms.misc.Gunzip")
# 210522-18:30:08,786 nipype.workflow INFO:
# 	 [Node] Finished "_gunzipfunc2".
# 210522-18:30:08,790 nipype.workflow INFO:
# 	 [Node] Finished "firs.gunzipfunc".
# 210522-18:30:08,791 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.get_prt_onsets" in "/tmp/tmpj4zimg0w/firs/_TR_700_sub_02/get_prt_onsets".
# 210522-18:30:08,796 nipype.workflow INFO:
# 	 [Node] Running "get_prt_onsets" ("nipype.interfaces.utility.wrappers.Function")
# 210522-18:30:08,802 nipype.workflow INFO:
# 	 [Node] Finished "firs.get_prt_onsets".
# 210522-18:30:08,803 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.selectOnsets" in "/tmp/tmpizxaqmj4/firs/_TR_700_sub_02/selectOnsets".
# 210522-18:30:08,819 nipype.workflow INFO:
# 	 [Node] Running "selectOnsets" ("nipype.interfaces.utility.wrappers.Function")
# 210522-18:30:08,826 nipype.workflow INFO:
# 	 [Node] Finished "firs.selectOnsets".
# 210522-18:30:08,827 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.modelspec" in "/tmp/tmpsm52qw9a/firs/_TR_700_sub_02/modelspec".
# 210522-18:30:08,840 nipype.workflow INFO:
# 	 [Node] Running "modelspec" ("nipype.algorithms.modelgen.SpecifySPMModel")
# 210522-18:30:09,158 nipype.workflow INFO:
# 	 [Node] Finished "firs.modelspec".
# 210522-18:30:09,159 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.level1design" in "/tmp/tmpzs0qfnzj/firs/_TR_700_sub_02/level1design".
# 210522-18:30:10,35 nipype.workflow INFO:
# 	 [Node] Running "level1design" ("nipype.interfaces.spm.model.Level1Design")
# 210522-18:31:08,693 nipype.workflow INFO:
# 	 [Node] Finished "firs.level1design".
# 210522-18:31:08,695 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.sink-stuff" in "/tmp/tmplphu3ada/firs/_TR_700_sub_02/sink-stuff".
# 210522-18:31:08,706 nipype.workflow INFO:
# 	 [Node] Running "sink-stuff" ("nipype.interfaces.io.DataSink")
# 210522-18:31:08,708 nipype.interface INFO:
# 	 sub: /scratch/qbi/uqkgarn1/STRIWP1/derivatives/glmFIR/sub-02/TR700/FLGLM/_TR_700_sub_02/SPM.mat -> /scratch/qbi/uqkgarn1/STRIWP1/derivatives/glmFIR/sub-02/TR700/FLGLM//SPM.mat
# 210522-18:31:08,843 nipype.workflow INFO:
# 	 [Node] Finished "firs.sink-stuff".
# 210522-18:31:08,844 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.T2-grabber" in "/tmp/tmpaszwqu2g/firs/_TR_1920_sub_01/T2-grabber".
# 210522-18:31:08,850 nipype.workflow INFO:
# 	 [Node] Running "T2-grabber" ("nipype.interfaces.io.DataGrabber")
# 210522-18:31:08,859 nipype.workflow INFO:
# 	 [Node] Finished "firs.T2-grabber".
# 210522-18:31:08,859 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.get_TR" in "/tmp/tmp4t7toli6/firs/_TR_1920_sub_01/get_TR".
# 210522-18:31:08,863 nipype.workflow INFO:
# 	 [Node] Running "get_TR" ("nipype.interfaces.utility.wrappers.Function")
# 210522-18:31:08,867 nipype.workflow INFO:
# 	 [Node] Finished "firs.get_TR".
# 210522-18:31:08,868 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.m-zip" in "/tmp/tmpex8cchag/firs/_TR_1920_sub_01/m-zip".
# 210522-18:31:08,872 nipype.workflow INFO:
# 	 [Node] Running "m-zip" ("nipype.algorithms.misc.Gunzip")
# 210522-18:31:08,892 nipype.workflow INFO:
# 	 [Node] Finished "firs.m-zip".
# 210522-18:31:08,893 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.gunzipfunc" in "/tmp/tmpwngtfheh/firs/_TR_1920_sub_01/gunzipfunc".
# 210522-18:31:08,899 nipype.workflow INFO:
# 	 [Node] Setting-up "_gunzipfunc0" in "/tmp/tmpwngtfheh/firs/_TR_1920_sub_01/gunzipfunc/mapflow/_gunzipfunc0".
# 210522-18:31:08,903 nipype.workflow INFO:
# 	 [Node] Running "_gunzipfunc0" ("nipype.algorithms.misc.Gunzip")
# 210522-18:31:14,859 nipype.workflow INFO:
# 	 [Node] Finished "_gunzipfunc0".
# 210522-18:31:14,862 nipype.workflow INFO:
# 	 [Node] Setting-up "_gunzipfunc1" in "/tmp/tmpwngtfheh/firs/_TR_1920_sub_01/gunzipfunc/mapflow/_gunzipfunc1".
# 210522-18:31:14,866 nipype.workflow INFO:
# 	 [Node] Running "_gunzipfunc1" ("nipype.algorithms.misc.Gunzip")
# 210522-18:31:21,47 nipype.workflow INFO:
# 	 [Node] Finished "_gunzipfunc1".
# 210522-18:31:21,50 nipype.workflow INFO:
# 	 [Node] Finished "firs.gunzipfunc".
# 210522-18:31:21,51 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.get_prt_onsets" in "/tmp/tmp4oti_ymk/firs/_TR_1920_sub_01/get_prt_onsets".
# 210522-18:31:21,56 nipype.workflow INFO:
# 	 [Node] Running "get_prt_onsets" ("nipype.interfaces.utility.wrappers.Function")
# 210522-18:31:21,63 nipype.workflow INFO:
# 	 [Node] Finished "firs.get_prt_onsets".
# 210522-18:31:21,63 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.selectOnsets" in "/tmp/tmpee72n_ui/firs/_TR_1920_sub_01/selectOnsets".
# 210522-18:31:21,76 nipype.workflow INFO:
# 	 [Node] Running "selectOnsets" ("nipype.interfaces.utility.wrappers.Function")
# 210522-18:31:21,81 nipype.workflow INFO:
# 	 [Node] Finished "firs.selectOnsets".
# 210522-18:31:21,82 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.modelspec" in "/tmp/tmpsg4wpi0c/firs/_TR_1920_sub_01/modelspec".
# 210522-18:31:21,95 nipype.workflow INFO:
# 	 [Node] Running "modelspec" ("nipype.algorithms.modelgen.SpecifySPMModel")
# 210522-18:31:21,192 nipype.workflow INFO:
# 	 [Node] Finished "firs.modelspec".
# 210522-18:31:21,193 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.level1design" in "/tmp/tmpz0z63f5l/firs/_TR_1920_sub_01/level1design".
# 210522-18:31:21,463 nipype.workflow INFO:
# 	 [Node] Running "level1design" ("nipype.interfaces.spm.model.Level1Design")
# 210522-18:31:48,946 nipype.workflow INFO:
# 	 [Node] Finished "firs.level1design".
# 210522-18:31:48,947 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.sink-stuff" in "/tmp/tmpv2piheen/firs/_TR_1920_sub_01/sink-stuff".
# 210522-18:31:48,956 nipype.workflow INFO:
# 	 [Node] Running "sink-stuff" ("nipype.interfaces.io.DataSink")
# 210522-18:31:48,958 nipype.interface INFO:
# 	 sub: /scratch/qbi/uqkgarn1/STRIWP1/derivatives/glmFIR/sub-01/TR1920/FLGLM/_TR_1920_sub_01/SPM.mat -> /scratch/qbi/uqkgarn1/STRIWP1/derivatives/glmFIR/sub-01/TR1920/FLGLM//SPM.mat
# 210522-18:31:48,978 nipype.workflow INFO:
# 	 [Node] Finished "firs.sink-stuff".
# 210522-18:31:48,979 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.T2-grabber" in "/tmp/tmpja2ffq56/firs/_TR_1510_sub_01/T2-grabber".
# 210522-18:31:48,984 nipype.workflow INFO:
# 	 [Node] Running "T2-grabber" ("nipype.interfaces.io.DataGrabber")
# 210522-18:31:48,993 nipype.workflow INFO:
# 	 [Node] Finished "firs.T2-grabber".
# 210522-18:31:48,993 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.get_TR" in "/tmp/tmphsa7ziyd/firs/_TR_1510_sub_01/get_TR".
# 210522-18:31:48,997 nipype.workflow INFO:
# 	 [Node] Running "get_TR" ("nipype.interfaces.utility.wrappers.Function")
# 210522-18:31:49,2 nipype.workflow INFO:
# 	 [Node] Finished "firs.get_TR".
# 210522-18:31:49,2 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.m-zip" in "/tmp/tmp580ni6wg/firs/_TR_1510_sub_01/m-zip".
# 210522-18:31:49,6 nipype.workflow INFO:
# 	 [Node] Running "m-zip" ("nipype.algorithms.misc.Gunzip")
# 210522-18:31:49,27 nipype.workflow INFO:
# 	 [Node] Finished "firs.m-zip".
# 210522-18:31:49,28 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.gunzipfunc" in "/tmp/tmpjc3pvl_m/firs/_TR_1510_sub_01/gunzipfunc".
# 210522-18:31:49,33 nipype.workflow INFO:
# 	 [Node] Setting-up "_gunzipfunc0" in "/tmp/tmpjc3pvl_m/firs/_TR_1510_sub_01/gunzipfunc/mapflow/_gunzipfunc0".
# 210522-18:31:49,36 nipype.workflow INFO:
# 	 [Node] Running "_gunzipfunc0" ("nipype.algorithms.misc.Gunzip")
# 210522-18:31:56,738 nipype.workflow INFO:
# 	 [Node] Finished "_gunzipfunc0".
# 210522-18:31:56,740 nipype.workflow INFO:
# 	 [Node] Setting-up "_gunzipfunc1" in "/tmp/tmpjc3pvl_m/firs/_TR_1510_sub_01/gunzipfunc/mapflow/_gunzipfunc1".
# 210522-18:31:56,744 nipype.workflow INFO:
# 	 [Node] Running "_gunzipfunc1" ("nipype.algorithms.misc.Gunzip")
# 210522-18:32:04,278 nipype.workflow INFO:
# 	 [Node] Finished "_gunzipfunc1".
# 210522-18:32:04,281 nipype.workflow INFO:
# 	 [Node] Finished "firs.gunzipfunc".
# 210522-18:32:04,282 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.get_prt_onsets" in "/tmp/tmp3qcy4f7l/firs/_TR_1510_sub_01/get_prt_onsets".
# 210522-18:32:04,288 nipype.workflow INFO:
# 	 [Node] Running "get_prt_onsets" ("nipype.interfaces.utility.wrappers.Function")
# 210522-18:32:04,294 nipype.workflow INFO:
# 	 [Node] Finished "firs.get_prt_onsets".
# 210522-18:32:04,294 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.selectOnsets" in "/tmp/tmptzy6f45b/firs/_TR_1510_sub_01/selectOnsets".
# 210522-18:32:04,306 nipype.workflow INFO:
# 	 [Node] Running "selectOnsets" ("nipype.interfaces.utility.wrappers.Function")
# 210522-18:32:04,312 nipype.workflow INFO:
# 	 [Node] Finished "firs.selectOnsets".
# 210522-18:32:04,313 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.modelspec" in "/tmp/tmp0odo6n8c/firs/_TR_1510_sub_01/modelspec".
# 210522-18:32:04,323 nipype.workflow INFO:
# 	 [Node] Running "modelspec" ("nipype.algorithms.modelgen.SpecifySPMModel")
# 210522-18:32:04,433 nipype.workflow INFO:
# 	 [Node] Finished "firs.modelspec".
# 210522-18:32:04,434 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.level1design" in "/tmp/tmpmg2hxefa/firs/_TR_1510_sub_01/level1design".
# 210522-18:32:04,751 nipype.workflow INFO:
# 	 [Node] Running "level1design" ("nipype.interfaces.spm.model.Level1Design")
# 210522-18:32:37,543 nipype.workflow INFO:
# 	 [Node] Finished "firs.level1design".
# 210522-18:32:37,545 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.sink-stuff" in "/tmp/tmpvh8k91gt/firs/_TR_1510_sub_01/sink-stuff".
# 210522-18:32:37,556 nipype.workflow INFO:
# 	 [Node] Running "sink-stuff" ("nipype.interfaces.io.DataSink")
# 210522-18:32:37,559 nipype.interface INFO:
# 	 sub: /scratch/qbi/uqkgarn1/STRIWP1/derivatives/glmFIR/sub-01/TR1510/FLGLM/_TR_1510_sub_01/SPM.mat -> /scratch/qbi/uqkgarn1/STRIWP1/derivatives/glmFIR/sub-01/TR1510/FLGLM//SPM.mat
# 210522-18:32:37,592 nipype.workflow INFO:
# 	 [Node] Finished "firs.sink-stuff".
# 210522-18:32:37,593 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.T2-grabber" in "/tmp/tmp1bjy9et2/firs/_TR_700_sub_01/T2-grabber".
# 210522-18:32:37,598 nipype.workflow INFO:
# 	 [Node] Running "T2-grabber" ("nipype.interfaces.io.DataGrabber")
# 210522-18:32:37,608 nipype.workflow INFO:
# 	 [Node] Finished "firs.T2-grabber".
# 210522-18:32:37,608 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.get_TR" in "/tmp/tmpfzzd7sju/firs/_TR_700_sub_01/get_TR".
# 210522-18:32:37,614 nipype.workflow INFO:
# 	 [Node] Running "get_TR" ("nipype.interfaces.utility.wrappers.Function")
# 210522-18:32:37,618 nipype.workflow INFO:
# 	 [Node] Finished "firs.get_TR".
# 210522-18:32:37,619 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.m-zip" in "/tmp/tmpls83kb9s/firs/_TR_700_sub_01/m-zip".
# 210522-18:32:37,623 nipype.workflow INFO:
# 	 [Node] Running "m-zip" ("nipype.algorithms.misc.Gunzip")
# 210522-18:32:37,636 nipype.workflow INFO:
# 	 [Node] Finished "firs.m-zip".
# 210522-18:32:37,637 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.gunzipfunc" in "/tmp/tmpuou32774/firs/_TR_700_sub_01/gunzipfunc".
# 210522-18:32:37,643 nipype.workflow INFO:
# 	 [Node] Setting-up "_gunzipfunc0" in "/tmp/tmpuou32774/firs/_TR_700_sub_01/gunzipfunc/mapflow/_gunzipfunc0".
# 210522-18:32:37,647 nipype.workflow INFO:
# 	 [Node] Running "_gunzipfunc0" ("nipype.algorithms.misc.Gunzip")
# 210522-18:32:43,292 nipype.workflow INFO:
# 	 [Node] Finished "_gunzipfunc0".
# 210522-18:32:43,301 nipype.workflow INFO:
# 	 [Node] Setting-up "_gunzipfunc1" in "/tmp/tmpuou32774/firs/_TR_700_sub_01/gunzipfunc/mapflow/_gunzipfunc1".
# 210522-18:32:43,308 nipype.workflow INFO:
# 	 [Node] Running "_gunzipfunc1" ("nipype.algorithms.misc.Gunzip")
# 210522-18:32:48,988 nipype.workflow INFO:
# 	 [Node] Finished "_gunzipfunc1".
# 210522-18:32:48,992 nipype.workflow INFO:
# 	 [Node] Finished "firs.gunzipfunc".
# 210522-18:32:48,993 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.get_prt_onsets" in "/tmp/tmpuhvzw9po/firs/_TR_700_sub_01/get_prt_onsets".
# 210522-18:32:49,1 nipype.workflow INFO:
# 	 [Node] Running "get_prt_onsets" ("nipype.interfaces.utility.wrappers.Function")
# 210522-18:32:49,9 nipype.workflow INFO:
# 	 [Node] Finished "firs.get_prt_onsets".
# 210522-18:32:49,9 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.selectOnsets" in "/tmp/tmp0yjllay8/firs/_TR_700_sub_01/selectOnsets".
# 210522-18:32:49,23 nipype.workflow INFO:
# 	 [Node] Running "selectOnsets" ("nipype.interfaces.utility.wrappers.Function")
# 210522-18:32:49,29 nipype.workflow INFO:
# 	 [Node] Finished "firs.selectOnsets".
# 210522-18:32:49,30 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.modelspec" in "/tmp/tmp35imzlf1/firs/_TR_700_sub_01/modelspec".
# 210522-18:32:49,41 nipype.workflow INFO:
# 	 [Node] Running "modelspec" ("nipype.algorithms.modelgen.SpecifySPMModel")
# 210522-18:32:49,245 nipype.workflow INFO:
# 	 [Node] Finished "firs.modelspec".
# 210522-18:32:49,245 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.level1design" in "/tmp/tmpl5ofmd8v/firs/_TR_700_sub_01/level1design".
# 210522-18:32:49,778 nipype.workflow INFO:
# 	 [Node] Running "level1design" ("nipype.interfaces.spm.model.Level1Design")
# 210522-18:33:33,301 nipype.workflow INFO:
# 	 [Node] Finished "firs.level1design".
# 210522-18:33:33,303 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.sink-stuff" in "/tmp/tmpcj1t9swi/firs/_TR_700_sub_01/sink-stuff".
# 210522-18:33:33,312 nipype.workflow INFO:
# 	 [Node] Running "sink-stuff" ("nipype.interfaces.io.DataSink")
# 210522-18:33:33,314 nipype.interface INFO:
# 	 sub: /scratch/qbi/uqkgarn1/STRIWP1/derivatives/glmFIR/sub-01/TR700/FLGLM/_TR_700_sub_01/SPM.mat -> /scratch/qbi/uqkgarn1/STRIWP1/derivatives/glmFIR/sub-01/TR700/FLGLM//SPM.mat
# 210522-18:33:33,400 nipype.workflow INFO:
# 	 [Node] Finished "firs.sink-stuff".

# %% [markdown]
# At this point, the [regressors need to be de-orthogonalised (within condition)](https://www.jiscmail.ac.uk/cgi-bin/webadmin?A2=spm;f525092b.1508), so return to scratch and run the function redef_FIRs.m, prior to running notebook 9_run_FIR_models
