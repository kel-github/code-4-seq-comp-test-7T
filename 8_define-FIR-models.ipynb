# %% [markdown]
# # Run FIR model on pared down GLM

# %%
from bids.layout import BIDSLayout
from nipype.interfaces import afni 
from nipype.interfaces.io import BIDSDataGrabber, DataFinder, DataSink, DataGrabber
import nipype.pipeline as pe
import nipype as ni
from nipype.interfaces.utility import Function
import nipype.interfaces.fsl.maths as fsl
from nipype.interfaces import spm as spm
from nipype.algorithms import modelgen as mgen
from nipype.algorithms.misc import Gunzip 
import pandas as pd
import os, re, json
import nipype.utils.filemanip as fm
# https://nipype.readthedocs.io/en/0.11.0/users/spmmcr.html
#
# set spm path to copy with use edit of spm_fMRI_design.m [see: https://www.jiscmail.ac.uk/cgi-bin/webadmin?A2=spm;f525092b.1508]
# scratch/qbi/uqkgarn1
matlab_cmd = '/scratch/qbi/uqkgarn1/spm12-r7219/run_spm12.sh /opt/matlabmcr-2010a/v713/ script'
spm.SPMCommand.set_mlab_paths(matlab_cmd=matlab_cmd, use_mcr=True)
# Out:
# 201229-19:42:10,708 nipype.utils WARNING:
# 	 A newer version (1.5.1) of nipy/nipype is available. You are using 1.5.0

# %%
Basedir = "/scratch/qbi/uqkgarn1/STRIWP1/"
layout = BIDSLayout(Basedir)
subs = layout.get_subjects()

firs = pe.Workflow(name="firs") # workflow to run the analysis
# Out:
# /opt/miniconda-latest/envs/neuro/lib/python3.6/site-packages/bids/layout/models.py:102: FutureWarning: The 'extension' entity currently excludes the leading dot ('.'). As of version 0.14.0, it will include the leading dot. To suppress this warning and include the leading dot, use `bids.config.set_option('extension_initial_dot', True)`.
#   FutureWarning)

# %% [markdown]
# # grab and sink data

# %%
dgT2s = pe.Node(DataGrabber(infields=['sub', 'TR'], 
                            outfields=['func','motion','onsets','bjson','mask']), name='T2-grabber')
dgT2s.inputs.base_dir = "/scratch/qbi/uqkgarn1/STRIWP1/"
dgT2s.inputs.sort_filelist = True
dgT2s.inputs.template='*'
dgT2s.inputs.template_args = {'func': [['sub', 'sub', 'TR']],
                              'motion':[['sub', 'sub', 'TR']],
                              'onsets':[['sub', 'sub', 'TR']],
                              'bjson':[['sub', 'sub', 'TR']],
                              'mask':[['sub', 'sub', 'TR']]}
dgT2s.inputs.field_template = {'func': '/scratch/qbi/uqkgarn1/STRIWP1/derivatives/sub-%s/ses-*/func/sub-%s_*TR%s_space-T1w_desc-preproc_bold.nii.gz',
                               'motion': '/scratch/qbi/uqkgarn1/STRIWP1/derivatives/glm/sub-%s/ses-*/func/sub-%s_*-TR%s*desc-motion_regressors.txt',
                               'onsets': '/scratch/qbi/uqkgarn1/STRIWP1/derivatives/sub-%s/ses-*/func/sub-%s_*-TR%s_glm_onsets.json',
                               'bjson': '/scratch/qbi/uqkgarn1/STRIWP1/derivatives/sub-%s/ses-*/func/sub-%s_*-TR%s*space-T1w_desc-preproc_bold.json',
                               'mask': '/scratch/qbi/uqkgarn1/STRIWP1/derivatives/sub-%s/ses-02/func/sub-%s_*TR%s_space-T1w_desc-brain_mask.nii.gz'}

# %%
# # debugging
# dgT2s.inputs.sub = '01'
# dgT2s.inputs.TR = '1510'
# res = dgT2s.run()
# res.outputs

# %%
T2inf = pe.Node(ni.IdentityInterface(fields=['sub', 'TR']),
                   name='T2-info')
T2inf.iterables = [('sub', ['01', '02', '03', '04', '05']), ('TR', ['700', '1510', '1920'])]
#T2inf.iterables = [('sub', ['01']), ('TR', ['1510'])]
T2inf.iterables
# Out:
# [('sub', ['01', '02', '03', '04', '05']), ('TR', ['700', '1510', '1920'])]

# %%
def printSubPath(fullFilePath):
    # function to split filepath into constituent parts, then print string to add as input to DataSink for the container string
    # given the full filepath, this extracts the subject folder and TR strings for input
    # into DataSink
    import os
    import re
    fname = os.path.normpath(fullFilePath[0])
    fname
    l = fname.split(os.sep)
    TR = re.search('.*acq-TR([0-9]*)_.*',l[-1])
    TR = str(int(TR.group(1)))
    name = [s for s in l if re.search('sub', s)][0]
    name = [name, "TR"+TR]
    name
    name = '/'.join(name)
    return name

# %%
ds = pe.Node(DataSink(), name='sink-stuff')
ds.inputs.base_directory = "/scratch/qbi/uqkgarn1/STRIWP1/derivatives/glmFIR/"
substitutions = [('_TR_([0-9]*)_sub_([0-9]*)', '')]
ds.inputs.regexp_substitutions = substitutions

# %% [markdown]
# # design informatiano

# %% [markdown]
# #### Overall

# %%
# the input function should be a list of the prt files, taken across sessions, for each TR
def getOnsetsJson(input_files):
    from nipype.interfaces.base import Bunch
    import json
    prt_output = [] #prt=protocol
    count = 0
    for f in input_files: 
        count = count + 1
        with open(f, "r+") as file:
            data = json.load(file)
            prt_output.insert(count, 
                              Bunch(conditions=data['names'],
                                    onsets=data['onsets'],
                                    durations=data['durations']))
    return prt_output

# %%
getOnsets = pe.Node(Function(input_names=['input_files'],
                             output_names=['prt_output'],
                             function=getOnsetsJson),
                    name='get_prt_onsets')

# %% [markdown]
# #### Target onset

# %%
def nu_regressors_comb2(bunches, cond_a, cond_b, nunames):
    # Warning: some elements of this function are hard coded!
    # this function will take a prt output (attained from getOnsets node),
    # and will collapse the conditions listed in cond_a, and those listed in cond_b
    # and will make 2 new conditions, labelled nunames
    from nipype.interfaces.base import Bunch
    nu_output = []
    count = 0
    for bunch in bunches:
        count = count + 1
    
        idx_a = [i for i,c in enumerate(bunch.conditions) if c in cond_a]
        idx_b = [i for i,c in enumerate(bunch.conditions) if c in cond_b]
        nuonsets = [[o  for i in idx_a for o in bunch.onsets[i]],
                    [o  for i in idx_b for o in bunch.onsets[i]]]
        nu_output.insert(count, 
                         Bunch(conditions=nunames,
                               onsets=nuonsets,
                               durations=[[0],[0]]))
    return nu_output

# %%
collapseOnsets = pe.Node(Function(input_names=['bunches', 'cond_a', 'cond_b', 'nunames'],
                                  output_names=['nu_output'],
                                  function=nu_regressors_comb2),
                        name='collapseOnsets')
collapseOnsets.inputs.cond_a = ['att_left_5', 'att_left_8']
collapseOnsets.inputs.cond_b = ['att_right_5', 'att_right_8']
collapseOnsets.inputs.nunames = ['tgt_left', 'tgt_right']

# %% [markdown]
# #### response hand

# %%
def select_regressors(bunches, conditions):
    # this function allows you to isolate the regressors that match the list of conditions, 
    # and returns them in the prt format for spm12
    from nipype.interfaces.base import Bunch
    nu_output = []
    count = 0
    
    for bunch in bunches:
        count = count + 1
        idx = [i for i,c in enumerate(bunch.conditions) if c in conditions]
        nuonsets = []
        nudurs = []
        for i in idx:
            nuonsets.append(bunch.onsets[i])
            nudurs.append([0])
            
        nu_output.insert(count, 
                         Bunch(conditions=conditions,
                               onsets=nuonsets,
                               durations=nudurs))
    return nu_output

# %%
selectOnsets = pe.Node(Function(input_names=['bunches', 'conditions'],
                                output_names=['nu_output'],
                                function=select_regressors),
                        name='selectOnsets')
selectOnsets.inputs.conditions = ['left_hand', 'right_hand']

# %% [markdown]
# # Gunzip nodes

# %%
gunzipfunc = pe.MapNode(Gunzip(), name='gunzipfunc', iterfield=['in_file'])

# %%
gmask = pe.Node(Gunzip(), name='m-zip')

# %% [markdown]
# # Get the TR for the model spec

# %%
# the input function should be a list of the prt files, taken across sessions, for each TR
def getTRJson(input_files):
    import json
    with open(input_files[0], "r+") as file:
            data = json.load(file)
            TR = data['RepetitionTime'] 
    if TR < .5:
        TR = 1.92
    return TR

# %%
getTR = pe.Node(Function(input_names=['input_files'],
                         output_names=['TR'],
                         function=getTRJson),
                name='get_TR')

# %%
def printSavFol(TR):
    # function to append the TR to a name for the save folder
    name = "TR" + TR
    return name

# %% [markdown]
# # Specify GLM Model

# %%
# SpecifyModel - Generates SPM-specific Model
modelspec = pe.Node(mgen.SpecifySPMModel(concatenate_runs=False,
                                         input_units='secs',
                                         output_units='secs',
                                         high_pass_filter_cutoff=128),
                    name="modelspec")

# %% [markdown]
# # Generate design matrix

# %%
# Level1Design - Generates an SPM design matrix
level1design = pe.Node(spm.Level1Design(bases={'fir': {'length': 18,
                                                       'order': 9}},
                                 timing_units='secs',
                                 model_serial_correlations='FAST'),
                       name="level1design")

# %% [markdown]
# # Connect workflow (collapsed onsets)

# %%
firs.connect([(T2inf, dgT2s, [('sub',  'sub')]), 
              (T2inf, dgT2s, [('TR',   'TR')]),
              (dgT2s, ds, [(('motion', printSubPath),
                             'container')]),
              (dgT2s, getOnsets, [('onsets', 'input_files')]),
              (getOnsets, collapseOnsets, [('prt_output', 'bunches')]),
              (dgT2s, gunzipfunc, [('func', 'in_file')]),
              (dgT2s, gmask, [('mask', 'in_file')]),
              (dgT2s, getTR, [('bjson', 'input_files')]),
              
              (getTR, modelspec, [('TR', 'time_repetition')]),
              (dgT2s, modelspec, [('motion', 'realignment_parameters')]), 
              (collapseOnsets, modelspec, [('nu_output', 'subject_info')]),
              (gunzipfunc, modelspec, [('out_file', 'functional_runs')]),
              (getTR, level1design, [('TR', 'interscan_interval')]),
              (modelspec, level1design, [('session_info', 'session_info')]),
              (gmask, level1design, [('out_file', 'mask_image')]),
              (level1design, ds, [('spm_mat_file', 'FLGLM.@des')])
])

# %%
firs.run()
# Out:
# 201229-19:42:22,938 nipype.workflow INFO:
# 	 Workflow firs settings: ['check', 'execution', 'logging', 'monitoring']
# 201229-19:42:23,137 nipype.workflow INFO:
# 	 Running serially.
# 201229-19:42:23,140 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.T2-grabber" in "/tmp/tmp6bq19mds/firs/_TR_1920_sub_05/T2-grabber".
# 201229-19:42:23,145 nipype.workflow INFO:
# 	 [Node] Running "T2-grabber" ("nipype.interfaces.io.DataGrabber")
# 201229-19:42:23,170 nipype.workflow INFO:
# 	 [Node] Finished "firs.T2-grabber".
# 201229-19:42:23,172 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.get_TR" in "/tmp/tmpjz0lk1iv/firs/_TR_1920_sub_05/get_TR".
# 201229-19:42:23,176 nipype.workflow INFO:
# 	 [Node] Running "get_TR" ("nipype.interfaces.utility.wrappers.Function")
# 201229-19:42:23,181 nipype.workflow INFO:
# 	 [Node] Finished "firs.get_TR".
# 201229-19:42:23,181 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.m-zip" in "/tmp/tmp_1vlcr6z/firs/_TR_1920_sub_05/m-zip".
# 201229-19:42:23,185 nipype.workflow INFO:
# 	 [Node] Running "m-zip" ("nipype.algorithms.misc.Gunzip")
# 201229-19:42:23,215 nipype.workflow INFO:
# 	 [Node] Finished "firs.m-zip".
# 201229-19:42:23,216 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.gunzipfunc" in "/tmp/tmpxknyhljl/firs/_TR_1920_sub_05/gunzipfunc".
# 201229-19:42:23,221 nipype.workflow INFO:
# 	 [Node] Setting-up "_gunzipfunc0" in "/tmp/tmpxknyhljl/firs/_TR_1920_sub_05/gunzipfunc/mapflow/_gunzipfunc0".
# 201229-19:42:23,224 nipype.workflow INFO:
# 	 [Node] Running "_gunzipfunc0" ("nipype.algorithms.misc.Gunzip")
# 201229-19:42:28,869 nipype.workflow INFO:
# 	 [Node] Finished "_gunzipfunc0".
# 201229-19:42:28,871 nipype.workflow INFO:
# 	 [Node] Setting-up "_gunzipfunc1" in "/tmp/tmpxknyhljl/firs/_TR_1920_sub_05/gunzipfunc/mapflow/_gunzipfunc1".
# 201229-19:42:28,874 nipype.workflow INFO:
# 	 [Node] Running "_gunzipfunc1" ("nipype.algorithms.misc.Gunzip")
# 201229-19:42:34,527 nipype.workflow INFO:
# 	 [Node] Finished "_gunzipfunc1".
# 201229-19:42:34,529 nipype.workflow INFO:
# 	 [Node] Setting-up "_gunzipfunc2" in "/tmp/tmpxknyhljl/firs/_TR_1920_sub_05/gunzipfunc/mapflow/_gunzipfunc2".
# 201229-19:42:34,533 nipype.workflow INFO:
# 	 [Node] Running "_gunzipfunc2" ("nipype.algorithms.misc.Gunzip")
# 201229-19:42:40,108 nipype.workflow INFO:
# 	 [Node] Finished "_gunzipfunc2".
# 201229-19:42:40,114 nipype.workflow INFO:
# 	 [Node] Finished "firs.gunzipfunc".
# 201229-19:42:40,115 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.get_prt_onsets" in "/tmp/tmp4h6qzy89/firs/_TR_1920_sub_05/get_prt_onsets".
# 201229-19:42:40,120 nipype.workflow INFO:
# 	 [Node] Running "get_prt_onsets" ("nipype.interfaces.utility.wrappers.Function")
# 201229-19:42:40,183 nipype.workflow INFO:
# 	 [Node] Finished "firs.get_prt_onsets".
# 201229-19:42:40,184 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.collapseOnsets" in "/tmp/tmpcsabjcwt/firs/_TR_1920_sub_05/collapseOnsets".
# 201229-19:42:40,200 nipype.workflow INFO:
# 	 [Node] Running "collapseOnsets" ("nipype.interfaces.utility.wrappers.Function")
# 201229-19:42:40,206 nipype.workflow INFO:
# 	 [Node] Finished "firs.collapseOnsets".
# 201229-19:42:40,207 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.modelspec" in "/tmp/tmpb2ao4tuj/firs/_TR_1920_sub_05/modelspec".
# 201229-19:42:40,219 nipype.workflow INFO:
# 	 [Node] Running "modelspec" ("nipype.algorithms.modelgen.SpecifySPMModel")
# 201229-19:42:40,411 nipype.workflow INFO:
# 	 [Node] Finished "firs.modelspec".
# 201229-19:42:40,412 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.level1design" in "/tmp/tmpfiboyy3g/firs/_TR_1920_sub_05/level1design".
# 201229-19:42:40,759 nipype.workflow INFO:
# 	 [Node] Running "level1design" ("nipype.interfaces.spm.model.Level1Design")
# 201229-19:43:19,551 nipype.workflow INFO:
# 	 [Node] Finished "firs.level1design".
# 201229-19:43:19,553 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.sink-stuff" in "/tmp/tmp6kpb2r95/firs/_TR_1920_sub_05/sink-stuff".
# 201229-19:43:19,563 nipype.workflow INFO:
# 	 [Node] Running "sink-stuff" ("nipype.interfaces.io.DataSink")
# 201229-19:43:19,565 nipype.interface INFO:
# 	 sub: /scratch/qbi/uqkgarn1/STRIWP1/derivatives/glmFIR/sub-05/TR1920/FLGLM/_TR_1920_sub_05/SPM.mat -> /scratch/qbi/uqkgarn1/STRIWP1/derivatives/glmFIR/sub-05/TR1920/FLGLM//SPM.mat
# 201229-19:43:19,588 nipype.workflow INFO:
# 	 [Node] Finished "firs.sink-stuff".
# 201229-19:43:19,588 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.T2-grabber" in "/tmp/tmp3lbkbi96/firs/_TR_1510_sub_05/T2-grabber".
# 201229-19:43:19,593 nipype.workflow INFO:
# 	 [Node] Running "T2-grabber" ("nipype.interfaces.io.DataGrabber")
# 201229-19:43:19,609 nipype.workflow INFO:
# 	 [Node] Finished "firs.T2-grabber".
# 201229-19
nipype.workflow INFO:
# 	 [Node] Setting-up "firs.get_TR" in "/tmp/tmpformudjf/firs/_TR_700_sub_03/get_TR".
# 201229-19:51:21,757 nipype.workflow INFO:
# 	 [Node] Running "get_TR" ("nipype.interfaces.utility.wrappers.Function")
# 201229-19:51:21,761 nipype.workflow INFO:
# 	 [Node] Finished "firs.get_TR".
# 201229-19:51:21,762 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.m-zip" in "/tmp/tmpt8b6swa0/firs/_TR_700_sub_03/m-zip".
# 201229-19:51:21,766 nipype.workflow INFO:
# 	 [Node] Running "m-zip" ("nipype.algorithms.misc.Gunzip")
# 201229-19:51:21,802 nipype.workflow INFO:
# 	 [Node] Finished "firs.m-zip".
# 201229-19:51:21,802 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.gunzipfunc" in "/tmp/tmpqhs9sev0/firs/_TR_700_sub_03/gunzipfunc".
# 201229-19:51:21,807 nipype.workflow INFO:
# 	 [Node] Setting-up "_gunzipfunc0" in "/tmp/tmpqhs9sev0/firs/_TR_700_sub_03/gunzipfunc/mapflow/_gunzipfunc0".
# 201229-19:51:21,811 nipype.workflow INFO:
# 	 [Node] Running "_gunzipfunc0" ("nipype.algorithms.misc.Gunzip")
# 201229-19:51:35,60 nipype.workflow INFO:
# 	 [Node] Finished "_gunzipfunc0".
# 201229-19:51:35,63 nipype.workflow INFO:
# 	 [Node] Setting-up "_gunzipfunc1" in "/tmp/tmpqhs9sev0/firs/_TR_700_sub_03/gunzipfunc/mapflow/_gunzipfunc1".
# 201229-19:51:35,66 nipype.workflow INFO:
# 	 [Node] Running "_gunzipfunc1" ("nipype.algorithms.misc.Gunzip")
# 201229-19:51:44,985 nipype.workflow INFO:
# 	 [Node] Finished "_gunzipfunc1".
# 201229-19:51:44,987 nipype.workflow INFO:
# 	 [Node] Setting-up "_gunzipfunc2" in "/tmp/tmpqhs9sev0/firs/_TR_700_sub_03/gunzipfunc/mapflow/_gunzipfunc2".
# 201229-19:51:44,990 nipype.workflow INFO:
# 	 [Node] Running "_gunzipfunc2" ("nipype.algorithms.misc.Gunzip")
# 201229-19:51:55,36 nipype.workflow INFO:
# 	 [Node] Finished "_gunzipfunc2".
# 201229-19:51:55,39 nipype.workflow INFO:
# 	 [Node] Finished "firs.gunzipfunc".
# 201229-19:51:55,40 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.get_prt_onsets" in "/tmp/tmpn8mwyecj/firs/_TR_700_sub_03/get_prt_onsets".
# 201229-19:51:55,45 nipype.workflow INFO:
# 	 [Node] Running "get_prt_onsets" ("nipype.interfaces.utility.wrappers.Function")
# 201229-19:51:55,113 nipype.workflow INFO:
# 	 [Node] Finished "firs.get_prt_onsets".
# 201229-19:51:55,114 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.collapseOnsets" in "/tmp/tmp6g2do91u/firs/_TR_700_sub_03/collapseOnsets".
# 201229-19:51:55,129 nipype.workflow INFO:
# 	 [Node] Running "collapseOnsets" ("nipype.interfaces.utility.wrappers.Function")
# 201229-19:51:55,135 nipype.workflow INFO:
# 	 [Node] Finished "firs.collapseOnsets".
# 201229-19:51:55,136 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.modelspec" in "/tmp/tmpijyzhar4/firs/_TR_700_sub_03/modelspec".
# 201229-19:51:55,148 nipype.workflow INFO:
# 	 [Node] Running "modelspec" ("nipype.algorithms.modelgen.SpecifySPMModel")
# 201229-19:51:55,543 nipype.workflow INFO:
# 	 [Node] Finished "firs.modelspec".
# 201229-19:51:55,544 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.level1design" in "/tmp/tmpm8eykhh4/firs/_TR_700_sub_03/level1design".
# 201229-19:51:56,406 nipype.workflow INFO:
# 	 [Node] Running "level1design" ("nipype.interfaces.spm.model.Level1Design")
# 201229-19:52:57,921 nipype.workflow INFO:
# 	 [Node] Finished "firs.level1design".
# 201229-19:52:57,923 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.sink-stuff" in "/tmp/tmpammtqwmd/firs/_TR_700_sub_03/sink-stuff".
# 201229-19:52:57,934 nipype.workflow INFO:
# 	 [Node] Running "sink-stuff" ("nipype.interfaces.io.DataSink")
# 201229-19:52:57,936 nipype.interface INFO:
# 	 sub: /scratch/qbi/uqkgarn1/STRIWP1/derivatives/glmFIR/sub-03/TR700/FLGLM/_TR_700_sub_03/SPM.mat -> /scratch/qbi/uqkgarn1/STRIWP1/derivatives/glmFIR/sub-03/TR700/FLGLM//SPM.mat
# 201229-19:52:58,90 nipype.workflow INFO:
# 	 [Node] Finished "firs.sink-stuff".
# 201229-19:52:58,91 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.T2-grabber" in "/tmp/tmpk3rmtgtn/firs/_TR_1920_sub_02/T2-grabber".
# 201229-19:52:58,96 nipype.workflow INFO:
# 	 [Node] Running "T2-grabber" ("nipype.interfaces.io.DataGrabber")
# 201229-19:52:58,121 nipype.workflow INFO:
# 	 [Node] Finished "firs.T2-grabber".
# 201229-19:52:58,122 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.get_TR" in "/tmp/tmpuha7sr2r/firs/_TR_1920_sub_02/get_TR".
# 201229-19:52:58,127 nipype.workflow INFO:
# 	 [Node] Running "get_TR" ("nipype.interfaces.utility.wrappers.Function")
# 201229-19:52:58,132 nipype.workflow INFO:
# 	 [Node] Finished "firs.get_TR".
# 201229-19:52:58,133 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.m-zip" in "/tmp/tmp1ptt_tup/firs/_TR_1920_sub_02/m-zip".
# 201229-19:52:58,137 nipype.workflow INFO:
# 	 [Node] Running "m-zip" ("nipype.algorithms.misc.Gunzip")
# 201229-19:52:58,174 nipype.workflow INFO:
# 	 [Node] Finished "firs.m-zip".
# 201229-19:52:58,175 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.gunzipfunc" in "/tmp/tmp7154lgf7/firs/_TR_1920_sub_02/gunzipfunc".
# 201229-19:52:58,180 nipype.workflow INFO:
# 	 [Node] Setting-up "_gunzipfunc0" in "/tmp/tmp7154lgf7/firs/_TR_1920_sub_02/gunzipfunc/mapflow/_gunzipfunc0".
# 201229-19:52:58,183 nipype.workflow INFO:
# 	 [Node] Running "_gunzipfunc0" ("nipype.algorithms.misc.Gunzip")
# 201229-19:53:03,988 nipype.workflow INFO:
# 	 [Node] Finished "_gunzipfunc0".
# 201229-19:53:03,989 nipype.workflow INFO:
# 	 [Node] Setting-up "_gunzipfunc1" in "/tmp/tmp7154lgf7/firs/_TR_1920_sub_02/gunzipfunc/mapflow/_gunzipfunc1".
# 201229-19:53:03,993 nipype.workflow INFO:
# 	 [Node] Running "_gunzipfunc1" ("nipype.algorithms.misc.Gunzip")
# 201229-19:53:09,985 nipype.workflow INFO:
# 	 [Node] Finished "_gunzipfunc1".
# 201229-19:53:09,988 nipype.workflow INFO:
# 	 [Node] Setting-up "_gunzipfunc2" in "/tmp/tmp7154lgf7/firs/_TR_1920_sub_02/gunzipfunc/mapflow/_gunzipfunc2".
# 201229-19:53:09,992 nipype.workflow INFO:
# 	 [Node] Running "_gunzipfunc2" ("nipype.algorithms.misc.Gunzip")
# 201229-19:53:15,860 nipype.workflow INFO:
# 	 [Node] Finished "_gunzipfunc2".
# 201229-19:53:15,864 nipype.workflow INFO:
# 	 [Node] Finished "firs.gunzipfunc".
# 201229-19:53:15,864 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.get_prt_onsets" in "/tmp/tmp4nogbgm5/firs/_TR_1920_sub_02/get_prt_onsets".
# 201229-19:53:15,869 nipype.workflow INFO:
# 	 [Node] Running "get_prt_onsets" ("nipype.interfaces.utility.wrappers.Function")
# 201229-19:53:15,981 nipype.workflow INFO:
# 	 [Node] Finished "firs.get_prt_onsets".
# 201229-19:53:15,981 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.collapseOnsets" in "/tmp/tmp_o3ajo47/firs/_TR_1920_sub_02/collapseOnsets".
# 201229-19:53:15,997 nipype.workflow INFO:
# 	 [Node] Running "collapseOnsets" ("nipype.interfaces.utility.wrappers.Function")
# 201229-19:53:16,4 nipype.workflow INFO:
# 	 [Node] Finished "firs.collapseOnsets".
# 201229-19:53:16,4 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.modelspec" in "/tmp/tmpd6ehj71q/firs/_TR_1920_sub_02/modelspec".
# 201229-19:53:16,16 nipype.workflow INFO:
# 	 [Node] Running "modelspec" ("nipype.algorithms.modelgen.SpecifySPMModel")
# 201229-19:53:16,231 nipype.workflow INFO:
# 	 [Node] Finished "firs.modelspec".
# 201229-19:53:16,232 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.level1design" in "/tmp/tmp5we55ko0/firs/_TR_1920_sub_02/level1design".
# 201229-19:53:16,621 nipype.workflow INFO:
# 	 [Node] Running "level1design" ("nipype.interfaces.spm.model.Level1Design")
# 201229-19:53:54,628 nipype.workflow INFO:
# 	 [Node] Finished "firs.level1design".
# 201229-19:53:54,630 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.sink-stuff" in "/tmp/tmppi_rpj98/firs/_TR_1920_sub_02/sink-stuff".
# 201229-19:53:54,639 nipype.workflow INFO:
# 	 [Node] Running "sink-stuff" ("nipype.interfaces.io.DataSink")
# 201229-19:53:54,641 nipype.interface INFO:
# 	 sub: /scratch/qbi/uqkgarn1/STRIWP1/derivatives/glmFIR/sub-02/TR1920/FLGLM/_TR_1920_sub_02/SPM.mat -> /scratch/qbi/uqkgarn1/STRIWP1/derivatives/glmFIR/sub-02/TR1920/FLGLM//SPM.mat
# 201229-19:53:54,666 nipype.workflow INFO:
# 	 [Node] Finished "firs.sink-stuff".
# 201229-19:53:54,667 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.T2-grabber" in "/tmp/tmpn06rynel/firs/_TR_1510_sub_02/T2-grabber".
# 201229-19:53:54,671 nipype.workflow INFO:
# 	 [Node] Running "T2-grabber" ("nipype.interfaces.io.DataGrabber")
# 201229-19:53:54,685 nipype.workflow INFO:
# 	 [Node] Finished "firs.T2-grabber".
# 201229-19:53:54,686 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.get_TR" in "/tmp/tmpntesesyy/firs/_TR_1510_sub_02/get_TR".
# 201229-19:53:54,690 nipype.workflow INFO:
# 	 [Node] Running "get_TR" ("nipype.interfaces.utility.wrappers.Function")
# 201229-19:53:54,694 nipype.workflow INFO:
# 	 [Node] Finished "firs.get_TR".
# 201229-19:53:54,694 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.m-zip" in "/tmp/tmptr66f9na/firs/_TR_1510_sub_02/m-zip".
# 201229-19:53:54,698 nipype.workflow INFO:
# 	 [Node] Running "m-zip" ("nipype.algorithms.misc.Gunzip")
# 201229-19:53:54,745 nipype.workflow INFO:
# 	 [Node] Finished "firs.m-zip".
# 201229-19:53:54,745 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.gunzipfunc" in "/tmp/tmpywambsa8/firs/_TR_1510_sub_02/gunzipfunc".
# 201229-19:53:54,750 nipype.workflow INFO:
# 	 [Node] Setting-up "_gunzipfunc0" in "/tmp/tmpywambsa8/firs/_TR_1510_sub_02/gunzipfunc/mapflow/_gunzipfunc0".
# 201229-19:53:54,753 nipype.workflow INFO:
# 	 [Node] Running "_gunzipfunc0" ("nipype.algorithms.misc.Gunzip")
# 201229-19:54:03,537 nipype.workflow INFO:
# 	 [Node] Finished "_gunzipfunc0".
# 201229-19:54:03,539 nipype.workflow INFO:
# 	 [Node] Setting-up "_gunzipfunc1" in "/tmp/tmpywambsa8/firs/_TR_1510_sub_02/gunzipfunc/mapflow/_gunzipfunc1".
# 201229-19:54:03,543 nipype.workflow INFO:
# 	 [Node] Running "_gunzipfunc1" ("nipype.algorithms.misc.Gunzip")
# 201229-19:54:11,763 nipype.workflow INFO:
# 	 [Node] Finished "_gunzipfunc1".
# 201229-19:54:11,765 nipype.workflow INFO:
# 	 [Node] Setting-up "_gunzipfunc2" in "/tmp/tmpywambsa8/firs/_TR_1510_sub_02/gunzipfunc/mapflow/_gunzipfunc2".
# 201229-19:54:11,768 nipype.workflow INFO:
# 	 [Node] Running "_gunzipfunc2" ("nipype.algorithms.misc.Gunzip")
# 201229-19:54:19,907 nipype.workflow INFO:
# 	 [Node] Finished "_gunzipfunc2".
# 201229-19:54:19,910 nipype.workflow INFO:
# 	 [Node] Finished "firs.gunzipfunc".
# 201229-19:54:19,910 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.get_prt_onsets" in "/tmp/tmpwb3m63sr/firs/_TR_1510_sub_02/get_prt_onsets".
# 201229-19:54:19,915 nipype.workflow INFO:
# 	 [Node] Running "get_prt_onsets" ("nipype.interfaces.utility.wrappers.Function")
# 201229-19:54:19,979 nipype.workflow INFO:
# 	 [Node] Finished "firs.get_prt_onsets".
# 201229-19:54:19,979 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.collapseOnsets" in "/tmp/tmpp81qb9zn/firs/_TR_1510_sub_02/collapseOnsets".
# 201229-19:54:19,995 nipype.workflow INFO:
# 	 [Node] Running "collapseOnsets" ("nipype.interfaces.utility.wrappers.Function")
# 201229-19:54:20,1 nipype.workflow INFO:
# 	 [Node] Finished "firs.collapseOnsets".
# 201229-19:54:20,1 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.modelspec" in "/tmp/tmp8k27c28o/firs/_TR_1510_sub_02/modelspec".
# 201229-19:54:20,13 nipype.workflow INFO:
# 	 [Node] Running "modelspec" ("nipype.algorithms.modelgen.SpecifySPMModel")
# 201229-19:54:20,249 nipype.workflow INFO:
# 	 [Node] Finished "firs.modelspec".
# 201229-19:54:20,250 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.level1design" in "/tmp/tmp5m2w60y1/firs/_TR_1510_sub_02/level1design".
# 201229-19:54:20,774 nipype.workflow INFO:
# 	 [Node] Running "level1design" ("nipype.interfaces.spm.model.Level1Design")
# 201229-19:55:10,598 nipype.workflow INFO:
# 	 [Node] Finished "firs.level1design".
# 201229-19:55:10,599 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.sink-stuff" in "/tmp/tmpegra9w7_/firs/_TR_1510_sub_02/sink-stuff".
# 201229-19:55:10,610 nipype.workflow INFO:
# 	 [Node] Running "sink-stuff" ("nipype.interfaces.io.DataSink")
# 201229-19:55:10,612 nipype.interface INFO:
# 	 sub: /scratch/qbi/uqkgarn1/STRIWP1/derivatives/glmFIR/sub-02/TR1510/FLGLM/_TR_1510_sub_02/SPM.mat -> /scratch/qbi/uqkgarn1/STRIWP1/derivatives/glmFIR/sub-02/TR1510/FLGLM//SPM.mat
# 201229-19:55:10,654 nipype.workflow INFO:
# 	 [Node] Finished "firs.sink-stuff".
# 201229-19:55:10,655 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.T2-grabber" in "/tmp/tmpa1yz00u0/firs/_TR_700_sub_02/T2-grabber".
# 201229-19:55:10,660 nipype.workflow INFO:
# 	 [Node] Running "T2-grabber" ("nipype.interfaces.io.DataGrabber")
# 201229-19:55:10,678 nipype.workflow INFO:
# 	 [Node] Finished "firs.T2-grabber".
# 201229-19:55:10,679 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.get_TR" in "/tmp/tmpzflcciwh/firs/_TR_700_sub_02/get_TR".
# 201229-19:55:10,683 nipype.workflow INFO:
# 	 [Node] Running "get_TR" ("nipype.interfaces.utility.wrappers.Function")
# 201229-19:55:10,688 nipype.workflow INFO:
# 	 [Node] Finished "firs.get_TR".
# 201229-19:55:10,688 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.m-zip" in "/tmp/tmp5m9jancy/firs/_TR_700_sub_02/m-zip".
# 201229-19:55:10,692 nipype.workflow INFO:
# 	 [Node] Running "m-zip" ("nipype.algorithms.misc.Gunzip")
# 201229-19:55:10,721 nipype.workflow INFO:
# 	 [Node] Finished "firs.m-zip".
# 201229-19:55:10,722 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.gunzipfunc" in "/tmp/tmpfyu4te_8/firs/_TR_700_sub_02/gunzipfunc".
# 201229-19:55:10,728 nipype.workflow INFO:
# 	 [Node] Setting-up "_gunzipfunc0" in "/tmp/tmpfyu4te_8/firs/_TR_700_sub_02/gunzipfunc/mapflow/_gunzipfunc0".
# 201229-19:55:10,731 nipype.workflow INFO:
# 	 [Node] Running "_gunzipfunc0" ("nipype.algorithms.misc.Gunzip")
# 201229-19:55:21,90 nipype.workflow INFO:
# 	 [Node] Finished "_gunzipfunc0".
# 201229-19:55:21,92 nipype.workflow INFO:
# 	 [Node] Setting-up "_gunzipfunc1" in "/tmp/tmpfyu4te_8/firs/_TR_700_sub_02/gunzipfunc/mapflow/_gunzipfunc1".
# 201229-19:55:21,96 nipype.workflow INFO:
# 	 [Node] Running "_gunzipfunc1" ("nipype.algorithms.misc.Gunzip")
# 201229-19:55:31,367 nipype.workflow INFO:
# 	 [Node] Finished "_gunzipfunc1".
# 201229-19:55:31,369 nipype.workflow INFO:
# 	 [Node] Setting-up "_gunzipfunc2" in "/tmp/tmpfyu4te_8/firs/_TR_700_sub_02/gunzipfunc/mapflow/_gunzipfunc2".
# 201229-19:55:31,372 nipype.workflow INFO:
# 	 [Node] Running "_gunzipfunc2" ("nipype.algorithms.misc.Gunzip")
# 201229-19:55:41,468 nipype.workflow INFO:
# 	 [Node] Finished "_gunzipfunc2".
# 201229-19:55:41,471 nipype.workflow INFO:
# 	 [Node] Finished "firs.gunzipfunc".
# 201229-19:55:41,471 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.get_prt_onsets" in "/tmp/tmp98t4lval/firs/_TR_700_sub_02/get_prt_onsets".
# 201229-19:55:41,476 nipype.workflow INFO:
# 	 [Node] Running "get_prt_onsets" ("nipype.interfaces.utility.wrappers.Function")
# 201229-19:55:41,530 nipype.workflow INFO:
# 	 [Node] Finished "firs.get_prt_onsets".
# 201229-19:55:41,531 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.collapseOnsets" in "/tmp/tmp87q3aumc/firs/_TR_700_sub_02/collapseOnsets".
# 201229-19:55:41,545 nipype.workflow INFO:
# 	 [Node] Running "collapseOnsets" ("nipype.interfaces.utility.wrappers.Function")
# 201229-19:55:41,552 nipype.workflow INFO:
# 	 [Node] Finished "firs.collapseOnsets".
# 201229-19:55:41,552 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.modelspec" in "/tmp/tmpcfciwsb4/firs/_TR_700_sub_02/modelspec".
# 201229-19:55:41,564 nipype.workflow INFO:
# 	 [Node] Running "modelspec" ("nipype.algorithms.modelgen.SpecifySPMModel")
# 201229-19:55:41,924 nipype.workflow INFO:
# 	 [Node] Finished "firs.modelspec".
# 201229-19:55:41,925 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.level1design" in "/tmp/tmpaeo0rhfx/firs/_TR_700_sub_02/level1design".
# 201229-19:55:42,753 nipype.workflow INFO:
# 	 [Node] Running "level1design" ("nipype.interfaces.spm.model.Level1Design")
# 201229-19:56:37,980 nipype.workflow INFO:
# 	 [Node] Finished "firs.level1design".
# 201229-19:56:37,981 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.sink-stuff" in "/tmp/tmpop1ta3q9/firs/_TR_700_sub_02/sink-stuff".
# 201229-19:56:37,992 nipype.workflow INFO:
# 	 [Node] Running "sink-stuff" ("nipype.interfaces.io.DataSink")
# 201229-19:56:37,994 nipype.interface INFO:
# 	 sub: /scratch/qbi/uqkgarn1/STRIWP1/derivatives/glmFIR/sub-02/TR700/FLGLM/_TR_700_sub_02/SPM.mat -> /scratch/qbi/uqkgarn1/STRIWP1/derivatives/glmFIR/sub-02/TR700/FLGLM//SPM.mat
# 201229-19:56:38,131 nipype.workflow INFO:
# 	 [Node] Finished "firs.sink-stuff".
# 201229-19:56:38,132 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.T2-grabber" in "/tmp/tmpka1nfmbe/firs/_TR_1920_sub_01/T2-grabber".
# 201229-19:56:38,138 nipype.workflow INFO:
# 	 [Node] Running "T2-grabber" ("nipype.interfaces.io.DataGrabber")
# 201229-19:56:38,151 nipype.workflow INFO:
# 	 [Node] Finished "firs.T2-grabber".
# 201229-19:56:38,151 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.get_TR" in "/tmp/tmp6ygaj2j5/firs/_TR_1920_sub_01/get_TR".
# 201229-19:56:38,155 nipype.workflow INFO:
# 	 [Node] Running "get_TR" ("nipype.interfaces.utility.wrappers.Function")
# 201229-19:56:38,160 nipype.workflow INFO:
# 	 [Node] Finished "firs.get_TR".
# 201229-19:56:38,160 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.m-zip" in "/tmp/tmpsus1jl_x/firs/_TR_1920_sub_01/m-zip".
# 201229-19:56:38,164 nipype.workflow INFO:
# 	 [Node] Running "m-zip" ("nipype.algorithms.misc.Gunzip")
# 201229-19:56:38,202 nipype.workflow INFO:
# 	 [Node] Finished "firs.m-zip".
# 201229-19:56:38,203 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.gunzipfunc" in "/tmp/tmpzfpraonf/firs/_TR_1920_sub_01/gunzipfunc".
# 201229-19:56:38,208 nipype.workflow INFO:
# 	 [Node] Setting-up "_gunzipfunc0" in "/tmp/tmpzfpraonf/firs/_TR_1920_sub_01/gunzipfunc/mapflow/_gunzipfunc0".
# 201229-19:56:38,211 nipype.workflow INFO:
# 	 [Node] Running "_gunzipfunc0" ("nipype.algorithms.misc.Gunzip")
# 201229-19:56:44,262 nipype.workflow INFO:
# 	 [Node] Finished "_gunzipfunc0".
# 201229-19:56:44,263 nipype.workflow INFO:
# 	 [Node] Setting-up "_gunzipfunc1" in "/tmp/tmpzfpraonf/firs/_TR_1920_sub_01/gunzipfunc/mapflow/_gunzipfunc1".
# 201229-19:56:44,266 nipype.workflow INFO:
# 	 [Node] Running "_gunzipfunc1" ("nipype.algorithms.misc.Gunzip")
# 201229-19:56:50,130 nipype.workflow INFO:
# 	 [Node] Finished "_gunzipfunc1".
# 201229-19:56:50,133 nipype.workflow INFO:
# 	 [Node] Finished "firs.gunzipfunc".
# 201229-19:56:50,134 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.get_prt_onsets" in "/tmp/tmpnizsysh4/firs/_TR_1920_sub_01/get_prt_onsets".
# 201229-19:56:50,138 nipype.workflow INFO:
# 	 [Node] Running "get_prt_onsets" ("nipype.interfaces.utility.wrappers.Function")
# 201229-19:56:50,189 nipype.workflow INFO:
# 	 [Node] Finished "firs.get_prt_onsets".
# 201229-19:56:50,189 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.collapseOnsets" in "/tmp/tmp2yg8o1mq/firs/_TR_1920_sub_01/collapseOnsets".
# 201229-19:56:50,201 nipype.workflow INFO:
# 	 [Node] Running "collapseOnsets" ("nipype.interfaces.utility.wrappers.Function")
# 201229-19:56:50,207 nipype.workflow INFO:
# 	 [Node] Finished "firs.collapseOnsets".
# 201229-19:56:50,208 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.modelspec" in "/tmp/tmprskag1d3/firs/_TR_1920_sub_01/modelspec".
# 201229-19:56:50,218 nipype.workflow INFO:
# 	 [Node] Running "modelspec" ("nipype.algorithms.modelgen.SpecifySPMModel")
# 201229-19:56:50,361 nipype.workflow INFO:
# 	 [Node] Finished "firs.modelspec".
# 201229-19:56:50,362 nipype.workflow INFO:
# 	 [Node] Setting-up "firs.level1design" in "/tmp/tmpckojp_g9/firs/_TR_1920_sub_01/level1design".
# 201229-19:56:50,605 nipype.workflow INFO:
# 	 [Node] Running "level1design" ("nipype.interfaces.spm.model.Level1Design")
# 201229-19